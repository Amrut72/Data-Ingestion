# %%
import psycopg2
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
import pandas as pd
import traceback

# %%
pd.set_option('display.max_columns',30)

pd.set_option('display.max_rows',500)

# %%
# Input to the function should be (DB server, new DB name, user, pwd)
# This function will create new DB using existing DB and setup the connection with returning cur

def create_new_db(default_db, new_db, user, pwd):
    try: 
        with connection(default_db) as (conn, cur):
            cur.execute(f"DROP DATABASE IF EXISTS {Name}")
            cur.execute(f"CREATE DATABASE {Name}")
    except psycopg2.Error as e:
        print(e)

# %%
# This function will take cursor and List of attributes as a input.
# List should be in format ["ID INT", "Name VARCHAR(20)"]

def createTable(List, db_name, tableName):
    try:
        with connection(db_name) as (conn, cur):
            string = ""
            for i in List:
                string+= f"{i},"
            string = string[:-1]
            cur.execute(f"CREATE TABLE IF NOT EXISTS {tableName} ({string})")
            
    except psycopg2.Error as e:
        print(e)

# %%
from contextlib import contextmanager

@contextmanager
def connection(db_name):
    try: 
        conn_string = f"host=localhost dbname={db_name} user=postgres password=root"
        conn = psycopg2.connect(conn_string)
        cur = conn.cursor()
        yield (conn, cur)
        
    except Exception as e:
        traceback.print_tb(e.__traceback__)
        traceback.print_exc()
        print(e)
    
    finally :
        conn.commit()
        cur.close()
        conn.close()

# %%
def sql(db_name,query):
    with connection(db_name) as (conn, cur):
        cur.execute(query)
        if 'select' in query.lower():
            ret = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            DF = pd.DataFrame(ret, columns=column_names)
            return DF
    return "Done"

# %% [markdown]
# # Inserting bulk data in database
#
#
# Basic Syntax:
# https://www.postgresqltutorial.com/postgresql-tutorial/postgresql-insert-multiple-rows/
#
# Comparision of different methods:
#
# https://naysan.ca/2020/05/09/pandas-to-postgresql-using-psycopg2-bulk-insert-performance-benchmark/
#
# Future purpose for comparision of different methods:
# https://github.com/NaysanSaran/pandas2postgresql/blob/master/notebooks/Psycopg2_Bulk_Insert_Speed_Benchmark.ipynb
#
#
# Motivation to use cur.mogrify:
# Basically, executeMany will run SQL query for each record and cur.mogrify will return string as SQL query.
#
# https://stackoverflow.com/questions/8134602/psycopg2-insert-multiple-rows-with-one-query
# https://www.geeksforgeeks.org/python-psycopg2-insert-multiple-rows-with-one-query/
#
#
# What is cursor:
#
# The Cursor class of the psycopg library provide methods to execute the PostgreSQL commands in the database using python code. Using the methods of it you can execute SQL statements, fetch data from the result sets, call procedures. You can create Cursor object using the cursor() method of the Connection object/class
#
# Exception tracback:
#
# https://www.w3docs.com/snippets/python/how-do-i-print-an-exception-in-python.html#:~:text=You%20can%20print%20an%20exception,variable%20name%20for%20an%20exception.&text=You%20can%20also%20use%20the,detailed%20traceback%20of%20the%20exception.
#
# numpy datatype solution:
# https://stackoverflow.com/questions/50626058/psycopg2-cant-adapt-type-numpy-int64
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_records.html

# %%
def inserting_value(DF,db_name,table_name):
    try:
        # Basically we need list of tuples of records. We can not use DF.to_record function as it returned numpy objects
        # Which are not suitable here
        list_of_tuple = [tuple(row) for row in DF.itertuples(index=False)]
        
        # to get lenght of row
        length = len(list_of_tuple[0])

        # Just to get no. %s 
        string_format = (",").join(["%s"] * length)
        
        with connection(db_name) as (conn, cur):

            # get tuples in string format
            args = ','.join(cur.mogrify(f"({string_format})", i).decode('utf-8')
                for i in list_of_tuple)

            # real query
            query = f"INSERT INTO {table_name} VALUES " + (args)
            cur.execute(query)
        
    except Exception as e:
        traceback.print_tb(e.__traceback__)

# %%
import unittest
from mod_amr import inserting_value
from unittest.mock import patch, MagicMock
import pandas as pd

class test_mod(unittest.TestCase):
    
    @patch(mod_amr.connection)
    def test_insert(self, mock_connection):
        
        mock_conn = MagicMock()
        mock_cur = MagicMock()
        mock_cur.mogrify.return_value = [(),()]
        mock_cur.execute.return_value = None
        
        A = {'col1': [1,2],
            'col2':['A','B']}
        B = pd.DataFrame(A)
        
        mock_connection.return_value = (mock_conn, mock_cur)
        
        self.assertEqual(inserting_value(B,'random','table'),"INSERT INTO table VALUES (1,'A'), (2,'B')")

# %%
from collections import defaultdict

def Len_prod(x):
    try:
        if type(x) == float:
            return 0
        else:
            return len(x)
    except:
        return 0


def suggested_schema(DF):
    Map = defaultdict(lambda : "Define")
    Map['int64'] = 'INT' 
    Map['int32'] = 'INT' 
    Map['object'] ='VARCHAR'
    Map['float64'] ='double precision'
    Map['datetime64[ns]'] = 'Date'
    col = list(DF.columns)
    schema = ""
    schema_list = []
    for i in range(len(col)):
        try:
            if Map[str(list(DF.dtypes)[i])] == 'VARCHAR':
                #print(Map[str(list(DF.dtypes)[i])], col[i])
                schema = col[i] + ' ' + Map[str(list(DF.dtypes)[i])] + '(' + str(DF[col[i]].apply(Len_prod).max()) + ')' 
            else:
                #print(Map[str(list(DF.dtypes)[i])], col[i])
                schema = col[i] + ' ' + Map[str(list(DF.dtypes)[i])]
            schema_list.append(schema)
        except:
            schema_list.append(col[i] + ' ' + 'Excepted col')
            continue
    return schema_list

# suggested_schema(result)

# str(DF[col[i]].apply(len).max()) --> Apply len function on every element of series object and then we find max of that list.
# Map[str(list(DF.dtypes)[i])] --> DF.dtypes numpy object which we need to convert into string.
# Len_prod was made for handling null values

# %%
def date_modification(x):
    Y = x[:6]
    if int(x[6:]) >= 50 and int(x[6:]) <= 99:
        Y = Y + '19' + x[6:]
    else:
        Y = Y + '20' + x[6:]
    return Y

# %%
## Creating circuit DF in pandas

circuits = pd.read_csv("C:\\Users\\91942\\Desktop\\Big Data\\DataSets\\archive\\circuits.csv")

# %%
pd.DataFrame(circuits.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   circuitId   79 non-null     int64
#  1   circuitRef  79 non-null     object
#  2   name        79 non-null     object
#  3   location    79 non-null     object
#  4   country     79 non-null     object
#  5   lat         79 non-null     float64
#  6   lng         79 non-null     float64
#  7   alt         79 non-null     int32
#  8   url         79 non-null     object
# dtypes: float64(2), int32(1), int64(1), object(5)
# memory usage: 5.4+ KB
# Empty DataFrame
# Columns: []
# Index: []

# %%
circuitSchema = ["circuitId INT PRIMARY KEY", "circuitRef VARCHAR(25)", "name VARCHAR(50)", "location VARCHAR(50)", "country VARCHAR(20)", "lat double precision", "lng double precision", "alt INT", "url VARCHAR(100)"]

# %%
createTable(circuitSchema,"formulaone","circuits")

# %%
circuits['alt'].unique()
# Out:
# array(['10', '18', '7', '109', '130', '13', '228', '153', '103', '264',
#        '4', '401', '162', '583', '5', '785', '223', '578', '37', '45',
#        '678', '3', '8', '266', '58', '1460', '88', '2227', '345', '432',
#        '0', '1126', '177', '145', '6', '36', '484', '139', '12', '639',
#        '609', '485', '332', '79', '790', '214', '81', '67', '15', '676',
#        '20', '28', '470', '53', '158', '19', '129', '551', '85', '194',
#        '161', '2', '-7', '9', '108', '255', '\\N'], dtype=object)

# %%
circuits.loc[circuits['alt'] == '\\N']
# Out:
#     circuitId circuitRef                           name   location country  \
# 77         78     losail   Losail International Circuit  Al Daayen   Qatar
# 78         79      miami  Miami International Autodrome      Miami     USA
#
#         lat      lng alt                                                url
# 77  25.4900  51.4542  \N  http://en.wikipedia.org/wiki/Losail_Internatio...
# 78  25.9581 -80.2389  \N  http://en.wikipedia.org/wiki/Miami_Internation...

# %%
circuits['alt'] = circuits['alt'].replace({'\\N':2}).astype('int')

# %%
circuits['alt'].unique()
# Out:
# array([  10,   18,    7,  109,  130,   13,  228,  153,  103,  264,    4,
#         401,  162,  583,    5,  785,  223,  578,   37,   45,  678,    3,
#           8,  266,   58, 1460,   88, 2227,  345,  432,    0, 1126,  177,
#         145,    6,   36,  484,  139,   12,  639,  609,  485,  332,   79,
#         790,  214,   81,   67,   15,  676,   20,   28,  470,   53,  158,
#          19,  129,  551,   85,  194,  161,    2,   -7,    9,  108,  255])

# %%
circuits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   circuitId   79 non-null     int64
#  1   circuitRef  79 non-null     object
#  2   name        79 non-null     object
#  3   location    79 non-null     object
#  4   country     79 non-null     object
#  5   lat         79 non-null     float64
#  6   lng         79 non-null     float64
#  7   alt         79 non-null     int32
#  8   url         79 non-null     object
# dtypes: float64(2), int32(1), int64(1), object(5)
# memory usage: 5.4+ KB

# %%
# To record is used to convert DataFrame to list of tuple..

circuits_tuple = circuits.to_records()

# %%
# inserting_value(circuits,'formulaone','circuits')

# %%
sql('formulaone',"SELECT circuitid FROM circuits")
# Out:
#     circuitid
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
# ..        ...
# 74         75
# 75         76
# 76         77
# 77         78
# 78         79
#
# [79 rows x 1 columns]

# %%
races = pd.read_csv("C:\\Users\\91942\\Desktop\\Big Data\\DataSets\\archive\\races.csv")

# %%
races
# Out:
#       raceId  year  round  circuitId                      name      date  \
# 0          1  2009      1          1     Australian Grand Prix  29/03/09
# 1          2  2009      2          2      Malaysian Grand Prix  05/04/09
# 2          3  2009      3         17        Chinese Grand Prix  19/04/09
# 3          4  2009      4          3        Bahrain Grand Prix  26/04/09
# 4          5  2009      5          4        Spanish Grand Prix  10/05/09
# ...      ...   ...    ...        ...                       ...       ...
# 1074    1092  2022     18         22       Japanese Grand Prix  09/10/22
# 1075    1093  2022     19         69  United States Grand Prix  23/10/22
# 1076    1094  2022     20         32    Mexico City Grand Prix  30/10/22
# 1077    1095  2022     21         18      Brazilian Grand Prix  13/11/22
# 1078    1096  2022     22         24      Abu Dhabi Grand Prix  20/11/22
#
#           time                                                url
# 0      6:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1      9:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2      7:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3     12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4     12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...
# ...        ...                                                ...
# 1074   5:00:00  http://en.wikipedia.org/wiki/2022_Japanese_Gra...
# 1075  19:00:00  http://en.wikipedia.org/wiki/2022_United_State...
# 1076  20:00:00  http://en.wikipedia.org/wiki/2022_Mexican_Gran...
# 1077  18:00:00  http://en.wikipedia.org/wiki/2022_Brazilian_Gr...
# 1078  13:00:00  http://en.wikipedia.org/wiki/2022_Abu_Dhabi_Gr...
#
# [1079 rows x 8 columns]

# %%
races.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1079 entries, 0 to 1078
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   raceId     1079 non-null   int64
#  1   year       1079 non-null   int64
#  2   round      1079 non-null   int64
#  3   circuitId  1079 non-null   int64
#  4   name       1079 non-null   object
#  5   date       1079 non-null   object
#  6   time       1079 non-null   object
#  7   url        1079 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 67.6+ KB

# %%
## Strictly execute this once after importing Dataframe

races['date'] = races['date'].apply(date_modification)

# %%
# list(races['date'].unique())

# %%
races['date'] = pd.to_datetime(races['date'], format="%d/%m/%Y")
races['date']
# Out:
# 0      2009-03-29
# 1      2009-04-05
# 2      2009-04-19
# 3      2009-04-26
# 4      2009-05-10
#           ...
# 1074   2022-10-09
# 1075   2022-10-23
# 1076   2022-10-30
# 1077   2022-11-13
# 1078   2022-11-20
# Name: date, Length: 1079, dtype: datetime64[ns]

# %%
races.loc[races['time'] == '\\N', 'time']
# Out:
# 89     \N
# 90     \N
# 91     \N
# 92     \N
# 93     \N
#        ..
# 834    \N
# 835    \N
# 836    \N
# 837    \N
# 838    \N
# Name: time, Length: 731, dtype: object

# %%
races['time'] = races['time'].replace("\\N","15:00:00")

# %% [markdown]
# #### Problem with time
#
# https://stackoverflow.com/questions/56816833/pandas-pd-to-datetime-only-keep-time-do-not-date

# %%
races['time'] = pd.to_datetime(races['time'],format="%H:%M:%S").dt.time
races['time'] = races['time'].astype(str)

# %%
races.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1079 entries, 0 to 1078
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   raceId     1079 non-null   int64
#  1   year       1079 non-null   int64
#  2   round      1079 non-null   int64
#  3   circuitId  1079 non-null   int64
#  4   name       1079 non-null   object
#  5   date       1079 non-null   datetime64[ns]
#  6   time       1079 non-null   object
#  7   url        1079 non-null   object
# dtypes: datetime64[ns](1), int64(4), object(3)
# memory usage: 67.6+ KB

# %%
print(suggested_schema(races))
# Out:
# ['raceId INT', 'year INT', 'round INT', 'circuitId INT', 'name VARCHAR(29)', 'date Date', 'time VARCHAR(8)', 'url VARCHAR(63)']

# %%
race_schema = ['raceId INT PRIMARY KEY', 'year INT', 'round INT', 'circuitId INT REFERENCES circuits(circuitId)', 'name VARCHAR(35)', 'date Date', 'time VARCHAR(8)', 'url VARCHAR(70)']

# %%
createTable(race_schema,"formulaone","races")

# %%
sql("formulaone", """SELECT table_name, column_name, data_type FROM information_schema.columns WHERE table_name = 'races'""")
# Out:
#   table_name column_name          data_type
# 0      races        date               date
# 1      races       round            integer
# 2      races      raceid            integer
# 3      races   circuitid            integer
# 4      races        year            integer
# 5      races         url  character varying
# 6      races        name  character varying
# 7      races        time  character varying

# %%
# sql("formulaone", """ALTER TABLE races ALTER COLUMN name TYPE VARCHAR(35)""")
# Out:
# 'Done'

# %%
inserting_value(races, 'formulaone', 'races')

# %%
sql("formulaone", """SELECT * FROM races""")
# Out:
#       raceid  year  round  circuitid                      name        date  \
# 0          1  2009      1          1     Australian Grand Prix  2009-03-29
# 1          2  2009      2          2      Malaysian Grand Prix  2009-05-04
# 2          3  2009      3         17        Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3        Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4        Spanish Grand Prix  2009-10-05
# ...      ...   ...    ...        ...                       ...         ...
# 1074    1092  2022     18         22       Japanese Grand Prix  2022-09-10
# 1075    1093  2022     19         69  United States Grand Prix  2022-10-23
# 1076    1094  2022     20         32    Mexico City Grand Prix  2022-10-30
# 1077    1095  2022     21         18      Brazilian Grand Prix  2022-11-13
# 1078    1096  2022     22         24      Abu Dhabi Grand Prix  2022-11-20
#
#           time                                                url
# 0     06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1     09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2     07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3     12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4     12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...
# ...        ...                                                ...
# 1074  05:00:00  http://en.wikipedia.org/wiki/2022_Japanese_Gra...
# 1075  19:00:00  http://en.wikipedia.org/wiki/2022_United_State...
# 1076  20:00:00  http://en.wikipedia.org/wiki/2022_Mexican_Gran...
# 1077  18:00:00  http://en.wikipedia.org/wiki/2022_Brazilian_Gr...
# 1078  13:00:00  http://en.wikipedia.org/wiki/2022_Abu_Dhabi_Gr...
#
# [1079 rows x 8 columns]

# %%
# sql("formulaone", """DROP TABLE circuits1""")
# Out:
# 'Done'

# %%
## Retired calculations


# races['name'].apply(len).max()

# %%
# Transformations Done are as follows:
# 1. Changed \\N to 72 and finally data type of Number to Int
# 2. Code col modified with surname 3 initials


drivers = pd.read_csv("C:\\Users\\91942\\Desktop\\Big Data\\DataSets\\archive\\drivers.csv", parse_dates=['dob'])

# %%
drivers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 854 entries, 0 to 853
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   driverId     854 non-null    int64
#  1   driverRef    854 non-null    object
#  2   number       854 non-null    object
#  3   code         854 non-null    object
#  4   forename     854 non-null    object
#  5   surname      854 non-null    object
#  6   dob          854 non-null    datetime64[ns]
#  7   nationality  854 non-null    object
#  8   url          854 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 60.2+ KB

# %%
drivers.head(1)
# Out:
#    driverId driverRef number code forename   surname        dob nationality  \
# 0         1  hamilton     44  HAM    Lewis  Hamilton 1985-01-07     British
#
#                                            url
# 0  http://en.wikipedia.org/wiki/Lewis_Hamilton

# %%
drivers['number'].unique()
# Out:
# array(['44', '\\N', '6', '14', '7', '88', '19', '99', '22', '5', '8',
#        '10', '27', '13', '11', '3', '25', '4', '21', '77', '17', '20',
#        '26', '45', '9', '28', '33', '12', '55', '98', '53', '30', '94',
#        '2', '31', '18', '16', '35', '63', '23', '51', '89', '47', '24'],
#       dtype=object)

# %%
drivers['number'].replace('\\N', 72, inplace=True)
drivers['number'] = drivers['number'].astype(int)

# %%
drivers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 854 entries, 0 to 853
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   driverId     854 non-null    int64
#  1   driverRef    854 non-null    object
#  2   number       854 non-null    int32
#  3   code         854 non-null    object
#  4   forename     854 non-null    object
#  5   surname      854 non-null    object
#  6   dob          854 non-null    datetime64[ns]
#  7   nationality  854 non-null    object
#  8   url          854 non-null    object
# dtypes: datetime64[ns](1), int32(1), int64(1), object(6)
# memory usage: 56.8+ KB

# %%
drivers.loc[drivers['code'] == '\\N','code'] = drivers.loc[drivers['code'] == '\\N']['surname'].apply(lambda x : x[:3].upper() if len(x[:3].upper().strip()) == 3 else x[:4].upper().replace(" ", ""))

# %%
drivers.loc[drivers['code'] == '\\N','code']
# Out:
# Series([], Name: code, dtype: object)

# %%
suggested_schema(drivers)
# Out:
# ['driverId INT',
#  'driverRef VARCHAR(18)',
#  'number INT',
#  'code VARCHAR(3)',
#  'forename VARCHAR(17)',
#  'surname VARCHAR(23)',
#  'dob Date',
#  'nationality VARCHAR(17)',
#  'url VARCHAR(83)']

# %%
driver_schema = ['driverId INT PRIMARY KEY','driverRef VARCHAR(18)', 'number INT','code VARCHAR(3)', 'forename VARCHAR(17)','surname VARCHAR(23)','dob Date','nationality VARCHAR(17)',
 'url VARCHAR(83)']

# %%
createTable(driver_schema,"formulaone","drivers")

# %%
inserting_value(drivers,"formulaone", "drivers")

# %%
sql("formulaone", "SELECT * FROM drivers")
# Out:
#      driverid        driverref  number code  forename     surname         dob  \
# 0           1         hamilton      44  HAM     Lewis    Hamilton  1985-01-07
# 1           2         heidfeld      72  HEI      Nick    Heidfeld  1977-05-10
# 2           3          rosberg       6  ROS      Nico     Rosberg  1985-06-27
# 3           4           alonso      14  ALO  Fernando      Alonso  1981-07-29
# 4           5       kovalainen      72  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...              ...     ...  ...       ...         ...         ...
# 849       851           aitken      89  AIT      Jack      Aitken  1995-09-23
# 850       852          tsunoda      22  TSU      Yuki     Tsunoda  2000-05-11
# 851       853          mazepin       9  MAZ    Nikita     Mazepin  1999-03-02
# 852       854  mick_schumacher      47  MSC      Mick  Schumacher  1999-03-22
# 853       855             zhou      24  ZHO    Guanyu        Zhou  1999-05-30
#
#     nationality                                             url
# 0       British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1        German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2        German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3       Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4       Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen
# ..          ...                                             ...
# 849     British        http://en.wikipedia.org/wiki/Jack_Aitken
# 850    Japanese       http://en.wikipedia.org/wiki/Yuki_Tsunoda
# 851     Russian     http://en.wikipedia.org/wiki/Nikita_Mazepin
# 852      German    http://en.wikipedia.org/wiki/Mick_Schumacher
# 853     Chinese        http://en.wikipedia.org/wiki/Guanyu_Zhou
#
# [854 rows x 9 columns]

# %%
# Retired Functions

# Used
# drivers.loc[drivers['code'] == '\\N']['surname'].apply(lambda x : x[:3].upper() if len(x[:3].upper(). strip()) == 3 else x[:4].upper().replace(" ", ""))


# Helped to see where error happend
# def Len(x):
#     print(x)
#     return len(x)


# snippet from suggested schema
# str(drivers['code'].apply(Len).max())


# Just checked and everything is of typr object... Not actually necessary
# filt = drivers['code'].apply(lambda x: isinstance(x,object))
# drivers.loc[~filt]


# This is very Helpful for checking where is the error happend
# list(drivers['code'].unique())

# %%
na_value_cust = ['\\N']
result = pd.read_csv("C:\\Users\\91942\\Desktop\\Big Data\\DataSets\\archive\\results.csv", na_values=na_value_cust)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25460 entries, 0 to 25459
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   resultId         25460 non-null  int64
#  1   raceId           25460 non-null  int64
#  2   driverId         25460 non-null  int64
#  3   constructorId    25460 non-null  int64
#  4   number           25454 non-null  float64
#  5   grid             25460 non-null  int64
#  6   position         14663 non-null  float64
#  7   positionText     25460 non-null  object
#  8   positionOrder    25460 non-null  int64
#  9   points           25460 non-null  float64
#  10  laps             25460 non-null  int64
#  11  time             6850 non-null   object
#  12  milliseconds     6849 non-null   float64
#  13  fastestLap       7010 non-null   float64
#  14  rank             7211 non-null   float64
#  15  fastestLapTime   7010 non-null   object
#  16  fastestLapSpeed  7010 non-null   float64
#  17  statusId         25460 non-null  int64
# dtypes: float64(7), int64(8), object(3)
# memory usage: 3.5+ MB

# %%
result.loc[result['points'] == 0,'position']
# Out:
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
#          ...
# 25455    16.0
# 25456    17.0
# 25457     NaN
# 25458     NaN
# 25459     NaN
# Name: position, Length: 17940, dtype: float64

# %%
result_races = result.merge(right=races ,right_on='raceId', left_on='raceId', how='inner')

# %%
list(races['date'].unique())
# Out:
# [numpy.datetime64('2009-03-29T00:00:00.000000000'),
#  numpy.datetime64('2009-05-04T00:00:00.000000000'),
#  numpy.datetime64('2009-04-19T00:00:00.000000000'),
#  numpy.datetime64('2009-04-26T00:00:00.000000000'),
#  numpy.datetime64('2009-10-05T00:00:00.000000000'),
#  numpy.datetime64('2009-05-24T00:00:00.000000000'),
#  numpy.datetime64('2009-07-06T00:00:00.000000000'),
#  numpy.datetime64('2009-06-21T00:00:00.000000000'),
#  numpy.datetime64('2009-12-07T00:00:00.000000000'),
#  numpy.datetime64('2009-07-26T00:00:00.000000000'),
#  numpy.datetime64('2009-08-23T00:00:00.000000000'),
#  numpy.datetime64('2009-08-30T00:00:00.000000000'),
#  numpy.datetime64('2009-09-13T00:00:00.000000000'),
#  numpy.datetime64('2009-09-27T00:00:00.000000000'),
#  numpy.datetime64('2009-04-10T00:00:00.000000000'),
#  numpy.datetime64('2009-10-18T00:00:00.000000000'),
#  numpy.datetime64('2009-01-11T00:00:00.000000000'),
#  numpy.datetime64('2008-03-16T00:00:00.000000000'),
#  numpy.datetime64('2008-03-23T00:00:00.000000000'),
#  numpy.datetime64('2008-06-04T00:00:00.000000000'),
#  numpy.datetime64('2008-04-27T00:00:00.000000000'),
#  numpy.datetime64('2008-11-05T00:00:00.000000000'),
#  numpy.datetime64('2008-05-25T00:00:00.000000000'),
#  numpy.datetime64('2008-08-06T00:00:00.000000000'),
#  numpy.datetime64('2008-06-22T00:00:00.000000000'),
#  numpy.datetime64('2008-06-07T00:00:00.000000000'),
#  numpy.datetime64('2008-07-20T00:00:00.000000000'),
#  numpy.datetime64('2008-03-08T00:00:00.000000000'),
#  numpy.datetime64('2008-08-24T00:00:00.000000000'),
#  numpy.datetime64('2008-07-09T00:00:00.000000000'),
#  numpy.datetime64('2008-09-14T00:00:00.000000000'),
#  numpy.datetime64('2008-09-28T00:00:00.000000000'),
#  numpy.datetime64('2008-12-10T00:00:00.000000000'),
#  numpy.datetime64('2008-10-19T00:00:00.000000000'),
#  numpy.datetime64('2008-02-11T00:00:00.000000000'),
#  numpy.datetime64('2007-03-18T00:00:00.000000000'),
#  numpy.datetime64('2007-08-04T00:00:00.000000000'),
#  numpy.datetime64('2007-04-15T00:00:00.000000000'),
#  numpy.datetime64('2007-05-13T00:00:00.000000000'),
#  numpy.datetime64('2007-05-27T00:00:00.000000000'),
#  numpy.datetime64('2007-10-06T00:00:00.000000000'),
#  numpy.datetime64('2007-06-17T00:00:00.000000000'),
#  numpy.datetime64('2007-01-07T00:00:00.000000000'),
#  numpy.datetime64('2007-08-07T00:00:00.000000000'),
#  numpy.datetime64('2007-07-22T00:00:00.000000000'),
#  numpy.datetime64('2007-05-08T00:00:00.000000000'),
#  numpy.datetime64('2007-08-26T00:00:00.000000000'),
#  numpy.datetime64('2007-09-09T00:00:00.000000000'),
#  numpy.datetime64('2007-09-16T00:00:00.000000000'),
#  numpy.datetime64('2007-09-30T00:00:00.000000000'),
#  numpy.datetime64('2007-07-10T00:00:00.000000000'),
#  numpy.datetime64('2007-10-21T00:00:00.000000000'),
#  numpy.datetime64('2006-12-03T00:00:00.000000000'),
#  numpy.datetime64('2006-03-19T00:00:00.000000000'),
#  numpy.datetime64('2006-02-04T00:00:00.000000000'),
#  numpy.datetime64('2006-04-23T00:00:00.000000000'),
#  numpy.datetime64('2006-07-05T00:00:00.000000000'),
#  numpy.datetime64('2006-05-14T00:00:00.000000000'),
#  numpy.datetime64('2006-05-28T00:00:00.000000000'),
#  numpy.datetime64('2006-11-06T00:00:00.000000000'),
#  numpy.datetime64('2006-06-25T00:00:00.000000000'),
#  numpy.datetime64('2006-02-07T00:00:00.000000000'),
#  numpy.datetime64('2006-07-16T00:00:00.000000000'),
#  numpy.datetime64('2006-07-30T00:00:00.000000000'),
#  numpy.datetime64('2006-06-08T00:00:00.000000000'),
#  numpy.datetime64('2006-08-27T00:00:00.000000000'),
#  numpy.datetime64('2006-10-09T00:00:00.000000000'),
#  numpy.datetime64('2006-01-10T00:00:00.000000000'),
#  numpy.datetime64('2006-08-10T00:00:00.000000000'),
#  numpy.datetime64('2006-10-22T00:00:00.000000000'),
#  numpy.datetime64('2005-06-03T00:00:00.000000000'),
#  numpy.datetime64('2005-03-20T00:00:00.000000000'),
#  numpy.datetime64('2005-03-04T00:00:00.000000000'),
#  numpy.datetime64('2005-04-24T00:00:00.000000000'),
#  numpy.datetime64('2005-08-05T00:00:00.000000000'),
#  numpy.datetime64('2005-05-22T00:00:00.000000000'),
#  numpy.datetime64('2005-05-29T00:00:00.000000000'),
#  numpy.datetime64('2005-12-06T00:00:00.000000000'),
#  numpy.datetime64('2005-06-19T00:00:00.000000000'),
#  numpy.datetime64('2005-03-07T00:00:00.000000000'),
#  numpy.datetime64('2005-10-07T00:00:00.000000000'),
#  numpy.datetime64('2005-07-24T00:00:00.000000000'),
#  numpy.datetime64('2005-07-31T00:00:00.000000000'),
#  numpy.datetime64('2005-08-21T00:00:00.000000000'),
#  numpy.datetime64('2005-04-09T00:00:00.000000000'),
#  numpy.datetime64('2005-11-09T00:00:00.000000000'),
#  numpy.datetime64('2005-09-25T00:00:00.000000000'),
#  numpy.datetime64('2005-09-10T00:00:00.000000000'),
#  numpy.datetime64('2005-10-16T00:00:00.000000000'),
#  numpy.datetime64('2004-07-03T00:00:00.000000000'),
#  numpy.datetime64('2004-03-21T00:00:00.000000000'),
#  numpy.datetime64('2004-04-04T00:00:00.000000000'),
#  numpy.datetime64('2004-04-25T00:00:00.000000000'),
#  numpy.datetime64('2004-09-05T00:00:00.000000000'),
#  numpy.datetime64('2004-05-23T00:00:00.000000000'),
#  numpy.datetime64('2004-05-30T00:00:00.000000000'),
#  numpy.datetime64('2004-06-13T00:00:00.000000000'),
#  numpy.datetime64('2004-06-20T00:00:00.000000000'),
#  numpy.datetime64('2004-04-07T00:00:00.000000000'),
#  numpy.datetime64('2004-11-07T00:00:00.000000000'),
#  numpy.datetime64('2004-07-25T00:00:00.000000000'),
#  numpy.datetime64('2004-08-15T00:00:00.000000000'),
#  numpy.datetime64('2004-08-29T00:00:00.000000000'),
#  numpy.datetime64('2004-12-09T00:00:00.000000000'),
#  numpy.datetime64('2004-09-26T00:00:00.000000000'),
#  numpy.datetime64('2004-10-10T00:00:00.000000000'),
#  numpy.datetime64('2004-10-24T00:00:00.000000000'),
#  numpy.datetime64('2003-09-03T00:00:00.000000000'),
#  numpy.datetime64('2003-03-23T00:00:00.000000000'),
#  numpy.datetime64('2003-06-04T00:00:00.000000000'),
#  numpy.datetime64('2003-04-20T00:00:00.000000000'),
#  numpy.datetime64('2003-04-05T00:00:00.000000000'),
#  numpy.datetime64('2003-05-18T00:00:00.000000000'),
#  numpy.datetime64('2003-01-06T00:00:00.000000000'),
#  numpy.datetime64('2003-06-15T00:00:00.000000000'),
#  numpy.datetime64('2003-06-29T00:00:00.000000000'),
#  numpy.datetime64('2003-06-07T00:00:00.000000000'),
#  numpy.datetime64('2003-07-20T00:00:00.000000000'),
#  numpy.datetime64('2003-03-08T00:00:00.000000000'),
#  numpy.datetime64('2003-08-24T00:00:00.000000000'),
#  numpy.datetime64('2003-09-14T00:00:00.000000000'),
#  numpy.datetime64('2003-09-28T00:00:00.000000000'),
#  numpy.datetime64('2003-12-10T00:00:00.000000000'),
#  numpy.datetime64('2002-03-03T00:00:00.000000000'),
#  numpy.datetime64('2002-03-17T00:00:00.000000000'),
#  numpy.datetime64('2002-03-31T00:00:00.000000000'),
#  numpy.datetime64('2002-04-14T00:00:00.000000000'),
#  numpy.datetime64('2002-04-28T00:00:00.000000000'),
#  numpy.datetime64('2002-12-05T00:00:00.000000000'),
#  numpy.datetime64('2002-05-26T00:00:00.000000000'),
#  numpy.datetime64('2002-09-06T00:00:00.000000000'),
#  numpy.datetime64('2002-06-23T00:00:00.000000000'),
#  numpy.datetime64('2002-07-07T00:00:00.000000000'),
#  numpy.datetime64('2002-07-21T00:00:00.000000000'),
#  numpy.datetime64('2002-07-28T00:00:00.000000000'),
#  numpy.datetime64('2002-08-18T00:00:00.000000000'),
#  numpy.datetime64('2002-01-09T00:00:00.000000000'),
#  numpy.datetime64('2002-09-15T00:00:00.000000000'),
#  numpy.datetime64('2002-09-29T00:00:00.000000000'),
#  numpy.datetime64('2002-10-13T00:00:00.000000000'),
#  numpy.datetime64('2001-04-03T00:00:00.000000000'),
#  numpy.datetime64('2001-03-18T00:00:00.000000000'),
#  numpy.datetime64('2001-01-04T00:00:00.000000000'),
#  numpy.datetime64('2001-04-15T00:00:00.000000000'),
#  numpy.datetime64('2001-04-29T00:00:00.000000000'),
#  numpy.datetime64('2001-05-13T00:00:00.000000000'),
#  numpy.datetime64('2001-05-27T00:00:00.000000000'),
#  numpy.datetime64('2001-10-06T00:00:00.000000000'),
#  numpy.datetime64('2001-06-24T00:00:00.000000000'),
#  numpy.datetime64('2001-01-07T00:00:00.000000000'),
#  numpy.datetime64('2001-07-15T00:00:00.000000000'),
#  numpy.datetime64('2001-07-29T00:00:00.000000000'),
#  numpy.datetime64('2001-08-19T00:00:00.000000000'),
#  numpy.datetime64('2001-02-09T00:00:00.000000000'),
#  numpy.datetime64('2001-09-16T00:00:00.000000000'),
#  numpy.datetime64('2001-09-30T00:00:00.000000000'),
#  numpy.datetime64('2001-10-14T00:00:00.000000000'),
#  numpy.datetime64('2000-12-03T00:00:00.000000000'),
#  numpy.datetime64('2000-03-26T00:00:00.000000000'),
#  numpy.datetime64('2000-09-04T00:00:00.000000000'),
#  numpy.datetime64('2000-04-23T00:00:00.000000000'),
#  numpy.datetime64('2000-07-05T00:00:00.000000000'),
#  numpy.datetime64('2000-05-21T00:00:00.000000000'),
#  numpy.datetime64('2000-04-06T00:00:00.000000000'),
#  numpy.datetime64('2000-06-18T00:00:00.000000000'),
#  numpy.datetime64('2000-02-07T00:00:00.000000000'),
#  numpy.datetime64('2000-07-16T00:00:00.000000000'),
#  numpy.datetime64('2000-07-30T00:00:00.000000000'),
#  numpy.datetime64('2000-08-13T00:00:00.000000000'),
#  numpy.datetime64('2000-08-27T00:00:00.000000000'),
#  numpy.datetime64('2000-10-09T00:00:00.000000000'),
#  numpy.datetime64('2000-09-24T00:00:00.000000000'),
#  numpy.datetime64('2000-08-10T00:00:00.000000000'),
#  numpy.datetime64('2000-10-22T00:00:00.000000000'),
#  numpy.datetime64('1999-07-03T00:00:00.000000000'),
#  numpy.datetime64('1999-11-04T00:00:00.000000000'),
#  numpy.datetime64('1999-02-05T00:00:00.000000000'),
#  numpy.datetime64('1999-05-16T00:00:00.000000000'),
#  numpy.datetime64('1999-05-30T00:00:00.000000000'),
#  numpy.datetime64('1999-06-13T00:00:00.000000000'),
#  numpy.datetime64('1999-06-27T00:00:00.000000000'),
#  numpy.datetime64('1999-11-07T00:00:00.000000000'),
#  numpy.datetime64('1999-07-25T00:00:00.000000000'),
#  numpy.datetime64('1999-01-08T00:00:00.000000000'),
#  numpy.datetime64('1999-08-15T00:00:00.000000000'),
#  numpy.datetime64('1999-08-29T00:00:00.000000000'),
#  numpy.datetime64('1999-12-09T00:00:00.000000000'),
#  numpy.datetime64('1999-09-26T00:00:00.000000000'),
#  numpy.datetime64('1999-10-17T00:00:00.000000000'),
#  numpy.datetime64('1999-10-31T00:00:00.000000000'),
#  numpy.datetime64('1998-08-03T00:00:00.000000000'),
#  numpy.datetime64('1998-03-29T00:00:00.000000000'),
#  numpy.datetime64('1998-12-04T00:00:00.000000000'),
#  numpy.datetime64('1998-04-26T00:00:00.000000000'),
#  numpy.datetime64('1998-10-05T00:00:00.000000000'),
#  numpy.datetime64('1998-05-24T00:00:00.000000000'),
#  numpy.datetime64('1998-07-06T00:00:00.000000000'),
#  numpy.datetime64('1998-06-28T00:00:00.000000000'),
#  numpy.datetime64('1998-12-07T00:00:00.000000000'),
#  numpy.datetime64('1998-07-26T00:00:00.000000000'),
#  numpy.datetime64('1998-02-08T00:00:00.000000000'),
#  numpy.datetime64('1998-08-16T00:00:00.000000000'),
#  numpy.datetime64('1998-08-30T00:00:00.000000000'),
#  numpy.datetime64('1998-09-13T00:00:00.000000000'),
#  numpy.datetime64('1998-09-27T00:00:00.000000000'),
#  numpy.datetime64('1998-01-11T00:00:00.000000000'),
#  numpy.datetime64('1997-09-03T00:00:00.000000000'),
#  numpy.datetime64('1997-03-30T00:00:00.000000000'),
#  numpy.datetime64('1997-04-13T00:00:00.000000000'),
#  numpy.datetime64('1997-04-27T00:00:00.000000000'),
#  numpy.datetime64('1997-11-05T00:00:00.000000000'),
#  numpy.datetime64('1997-05-25T00:00:00.000000000'),
#  numpy.datetime64('1997-06-15T00:00:00.000000000'),
#  numpy.datetime64('1997-06-29T00:00:00.000000000'),
#  numpy.datetime64('1997-07-13T00:00:00.000000000'),
#  numpy.datetime64('1997-07-27T00:00:00.000000000'),
#  numpy.datetime64('1997-10-08T00:00:00.000000000'),
#  numpy.datetime64('1997-08-24T00:00:00.000000000'),
#  numpy.datetime64('1997-07-09T00:00:00.000000000'),
#  numpy.datetime64('1997-09-21T00:00:00.000000000'),
#  numpy.datetime64('1997-09-28T00:00:00.000000000'),
#  numpy.datetime64('1997-12-10T00:00:00.000000000'),
#  numpy.datetime64('1997-10-26T00:00:00.000000000'),
#  numpy.datetime64('1996-10-03T00:00:00.000000000'),
#  numpy.datetime64('1996-03-31T00:00:00.000000000'),
#  numpy.datetime64('1996-07-04T00:00:00.000000000'),
#  numpy.datetime64('1996-04-28T00:00:00.000000000'),
#  numpy.datetime64('1996-05-05T00:00:00.000000000'),
#  numpy.datetime64('1996-05-19T00:00:00.000000000'),
#  numpy.datetime64('1996-02-06T00:00:00.000000000'),
#  numpy.datetime64('1996-06-16T00:00:00.000000000'),
#  numpy.datetime64('1996-06-30T00:00:00.000000000'),
#  numpy.datetime64('1996-07-14T00:00:00.000000000'),
#  numpy.datetime64('1996-07-28T00:00:00.000000000'),
#  numpy.datetime64('1996-11-08T00:00:00.000000000'),
#  numpy.datetime64('1996-08-25T00:00:00.000000000'),
#  numpy.datetime64('1996-08-09T00:00:00.000000000'),
#  numpy.datetime64('1996-09-22T00:00:00.000000000'),
#  numpy.datetime64('1996-10-13T00:00:00.000000000'),
#  numpy.datetime64('1995-03-26T00:00:00.000000000'),
#  numpy.datetime64('1995-09-04T00:00:00.000000000'),
#  numpy.datetime64('1995-04-30T00:00:00.000000000'),
#  numpy.datetime64('1995-05-14T00:00:00.000000000'),
#  numpy.datetime64('1995-05-28T00:00:00.000000000'),
#  numpy.datetime64('1995-11-06T00:00:00.000000000'),
#  numpy.datetime64('1995-02-07T00:00:00.000000000'),
#  numpy.datetime64('1995-07-16T00:00:00.000000000'),
#  numpy.datetime64('1995-07-30T00:00:00.000000000'),
#  numpy.datetime64('1995-08-13T00:00:00.000000000'),
#  numpy.datetime64('1995-08-27T00:00:00.000000000'),
#  numpy.datetime64('1995-10-09T00:00:00.000000000'),
#  numpy.datetime64('1995-09-24T00:00:00.000000000'),
#  numpy.datetime64('1995-01-10T00:00:00.000000000'),
#  numpy.datetime64('1995-10-22T00:00:00.000000000'),
#  numpy.datetime64('1995-10-29T00:00:00.000000000'),
#  numpy.datetime64('1995-12-11T00:00:00.000000000'),
#  numpy.datetime64('1994-03-27T00:00:00.000000000'),
#  numpy.datetime64('1994-04-17T00:00:00.000000000'),
#  numpy.datetime64('1994-01-05T00:00:00.000000000'),
#  numpy.datetime64('1994-05-15T00:00:00.000000000'),
#  numpy.datetime64('1994-05-29T00:00:00.000000000'),
#  numpy.datetime64('1994-12-06T00:00:00.000000000'),
#  numpy.datetime64('1994-03-07T00:00:00.000000000'),
#  numpy.datetime64('1994-10-07T00:00:00.000000000'),
#  numpy.datetime64('1994-07-31T00:00:00.000000000'),
#  numpy.datetime64('1994-08-14T00:00:00.000000000'),
#  numpy.datetime64('1994-08-28T00:00:00.000000000'),
#  numpy.datetime64('1994-11-09T00:00:00.000000000'),
#  numpy.datetime64('1994-09-25T00:00:00.000000000'),
#  numpy.datetime64('1994-10-16T00:00:00.000000000'),
#  numpy.datetime64('1994-06-11T00:00:00.000000000'),
#  numpy.datetime64('1994-11-13T00:00:00.000000000'),
#  numpy.datetime64('1993-03-14T00:00:00.000000000'),
#  numpy.datetime64('1993-03-28T00:00:00.000000000'),
#  numpy.datetime64('1993-11-04T00:00:00.000000000'),
#  numpy.datetime64('1993-04-25T00:00:00.000000000'),
#  numpy.datetime64('1993-09-05T00:00:00.000000000'),
#  numpy.datetime64('1993-05-23T00:00:00.000000000'),
#  numpy.datetime64('1993-06-13T00:00:00.000000000'),
#  numpy.datetime64('1993-04-07T00:00:00.000000000'),
#  numpy.datetime64('1993-11-07T00:00:00.000000000'),
#  numpy.datetime64('1993-07-25T00:00:00.000000000'),
#  numpy.datetime64('1993-08-15T00:00:00.000000000'),
#  numpy.datetime64('1993-08-29T00:00:00.000000000'),
#  numpy.datetime64('1993-12-09T00:00:00.000000000'),
#  numpy.datetime64('1993-09-26T00:00:00.000000000'),
#  numpy.datetime64('1993-10-24T00:00:00.000000000'),
#  numpy.datetime64('1993-07-11T00:00:00.000000000'),
#  numpy.datetime64('1992-01-03T00:00:00.000000000'),
#  numpy.datetime64('1992-03-22T00:00:00.000000000'),
#  numpy.datetime64('1992-05-04T00:00:00.000000000'),
#  numpy.datetime64('1992-03-05T00:00:00.000000000'),
#  numpy.datetime64('1992-05-17T00:00:00.000000000'),
#  numpy.datetime64('1992-05-31T00:00:00.000000000'),
#  numpy.datetime64('1992-06-14T00:00:00.000000000'),
#  numpy.datetime64('1992-05-07T00:00:00.000000000'),
#  numpy.datetime64('1992-12-07T00:00:00.000000000'),
#  numpy.datetime64('1992-07-26T00:00:00.000000000'),
#  numpy.datetime64('1992-08-16T00:00:00.000000000'),
#  numpy.datetime64('1992-08-30T00:00:00.000000000'),
#  numpy.datetime64('1992-09-13T00:00:00.000000000'),
#  numpy.datetime64('1992-09-27T00:00:00.000000000'),
#  numpy.datetime64('1992-10-25T00:00:00.000000000'),
#  numpy.datetime64('1992-08-11T00:00:00.000000000'),
#  numpy.datetime64('1991-10-03T00:00:00.000000000'),
#  numpy.datetime64('1991-03-24T00:00:00.000000000'),
#  numpy.datetime64('1991-04-28T00:00:00.000000000'),
#  numpy.datetime64('1991-12-05T00:00:00.000000000'),
#  numpy.datetime64('1991-02-06T00:00:00.000000000'),
#  numpy.datetime64('1991-06-16T00:00:00.000000000'),
#  numpy.datetime64('1991-07-07T00:00:00.000000000'),
#  numpy.datetime64('1991-07-14T00:00:00.000000000'),
#  numpy.datetime64('1991-07-28T00:00:00.000000000'),
#  numpy.datetime64('1991-11-08T00:00:00.000000000'),
#  numpy.datetime64('1991-08-25T00:00:00.000000000'),
#  numpy.datetime64('1991-08-09T00:00:00.000000000'),
#  numpy.datetime64('1991-09-22T00:00:00.000000000'),
#  numpy.datetime64('1991-09-29T00:00:00.000000000'),
#  numpy.datetime64('1991-10-20T00:00:00.000000000'),
#  numpy.datetime64('1991-03-11T00:00:00.000000000'),
#  numpy.datetime64('1990-11-03T00:00:00.000000000'),
#  numpy.datetime64('1990-03-25T00:00:00.000000000'),
#  numpy.datetime64('1990-05-13T00:00:00.000000000'),
#  numpy.datetime64('1990-05-27T00:00:00.000000000'),
#  numpy.datetime64('1990-10-06T00:00:00.000000000'),
#  numpy.datetime64('1990-06-24T00:00:00.000000000'),
#  numpy.datetime64('1990-08-07T00:00:00.000000000'),
#  numpy.datetime64('1990-07-15T00:00:00.000000000'),
#  numpy.datetime64('1990-07-29T00:00:00.000000000'),
#  numpy.datetime64('1990-12-08T00:00:00.000000000'),
#  numpy.datetime64('1990-08-26T00:00:00.000000000'),
#  numpy.datetime64('1990-09-09T00:00:00.000000000'),
#  numpy.datetime64('1990-09-23T00:00:00.000000000'),
#  numpy.datetime64('1990-09-30T00:00:00.000000000'),
#  numpy.datetime64('1990-10-21T00:00:00.000000000'),
#  numpy.datetime64('1990-04-11T00:00:00.000000000'),
#  numpy.datetime64('2010-03-14T00:00:00.000000000'),
#  numpy.datetime64('2010-03-28T00:00:00.000000000'),
#  numpy.datetime64('2010-04-04T00:00:00.000000000'),
#  numpy.datetime64('2010-04-18T00:00:00.000000000'),
#  numpy.datetime64('2010-09-05T00:00:00.000000000'),
#  numpy.datetime64('2010-05-16T00:00:00.000000000'),
#  numpy.datetime64('2010-05-30T00:00:00.000000000'),
#  numpy.datetime64('2010-06-13T00:00:00.000000000'),
#  numpy.datetime64('2010-06-27T00:00:00.000000000'),
#  numpy.datetime64('2010-11-07T00:00:00.000000000'),
#  numpy.datetime64('2010-07-25T00:00:00.000000000'),
#  numpy.datetime64('2010-01-08T00:00:00.000000000'),
#  numpy.datetime64('2010-08-29T00:00:00.000000000'),
#  numpy.datetime64('2010-12-09T00:00:00.000000000'),
#  numpy.datetime64('2010-09-26T00:00:00.000000000'),
#  numpy.datetime64('2010-10-10T00:00:00.000000000'),
#  numpy.datetime64('2010-10-24T00:00:00.000000000'),
#  numpy.datetime64('2010-07-11T00:00:00.000000000'),
#  numpy.datetime64('2010-11-14T00:00:00.000000000'),
#  numpy.datetime64('1989-03-26T00:00:00.000000000'),
#  numpy.datetime64('1989-04-23T00:00:00.000000000'),
#  numpy.datetime64('1989-07-05T00:00:00.000000000'),
#  numpy.datetime64('1989-05-28T00:00:00.000000000'),
#  numpy.datetime64('1989-04-06T00:00:00.000000000'),
#  numpy.datetime64('1989-06-18T00:00:00.000000000'),
#  numpy.datetime64('1989-09-07T00:00:00.000000000'),
#  numpy.datetime64('1989-07-16T00:00:00.000000000'),
#  numpy.datetime64('1989-07-30T00:00:00.000000000'),
#  numpy.datetime64('1989-08-13T00:00:00.000000000'),
#  numpy.datetime64('1989-08-27T00:00:00.000000000'),
#  numpy.datetime64('1989-10-09T00:00:00.000000000'),
#  numpy.datetime64('1989-09-24T00:00:00.000000000'),
#  numpy.datetime64('1989-01-10T00:00:00.000000000'),
#  numpy.datetime64('1989-10-22T00:00:00.000000000'),
#  numpy.datetime64('1989-05-11T00:00:00.000000000'),
#  numpy.datetime64('1988-03-04T00:00:00.000000000'),
#  numpy.datetime64('1988-01-05T00:00:00.000000000'),
#  numpy.datetime64('1988-05-15T00:00:00.000000000'),
#  numpy.datetime64('1988-05-29T00:00:00.000000000'),
#  numpy.datetime64('1988-12-06T00:00:00.000000000'),
#  numpy.datetime64('1988-06-19T00:00:00.000000000'),
#  numpy.datetime64('1988-03-07T00:00:00.000000000'),
#  numpy.datetime64('1988-10-07T00:00:00.000000000'),
#  numpy.datetime64('1988-07-24T00:00:00.000000000'),
#  numpy.datetime64('1988-07-08T00:00:00.000000000'),
#  numpy.datetime64('1988-08-28T00:00:00.000000000'),
#  numpy.datetime64('1988-11-09T00:00:00.000000000'),
#  numpy.datetime64('1988-09-25T00:00:00.000000000'),
#  numpy.datetime64('1988-02-10T00:00:00.000000000'),
#  numpy.datetime64('1988-10-30T00:00:00.000000000'),
#  numpy.datetime64('1988-11-13T00:00:00.000000000'),
#  numpy.datetime64('1987-12-04T00:00:00.000000000'),
#  numpy.datetime64('1987-03-05T00:00:00.000000000'),
#  numpy.datetime64('1987-05-17T00:00:00.000000000'),
#  numpy.datetime64('1987-05-31T00:00:00.000000000'),
#  numpy.datetime64('1987-06-21T00:00:00.000000000'),
#  numpy.datetime64('1987-05-07T00:00:00.000000000'),
#  numpy.datetime64('1987-12-07T00:00:00.000000000'),
#  numpy.datetime64('1987-07-26T00:00:00.000000000'),
#  numpy.datetime64('1987-09-08T00:00:00.000000000'),
#  numpy.datetime64('1987-08-16T00:00:00.000000000'),
#  numpy.datetime64('1987-06-09T00:00:00.000000000'),
#  numpy.datetime64('1987-09-20T00:00:00.000000000'),
#  numpy.datetime64('1987-09-27T00:00:00.000000000'),
#  numpy.datetime64('1987-10-18T00:00:00.000000000'),
#  numpy.datetime64('1987-01-11T00:00:00.000000000'),
#  numpy.datetime64('1987-11-15T00:00:00.000000000'),
#  numpy.datetime64('1986-03-23T00:00:00.000000000'),
#  numpy.datetime64('1986-04-13T00:00:00.000000000'),
#  numpy.datetime64('1986-04-27T00:00:00.000000000'),
#  numpy.datetime64('1986-11-05T00:00:00.000000000'),
#  numpy.datetime64('1986-05-25T00:00:00.000000000'),
#  numpy.datetime64('1986-06-15T00:00:00.000000000'),
#  numpy.datetime64('1986-06-22T00:00:00.000000000'),
#  numpy.datetime64('1986-06-07T00:00:00.000000000'),
#  numpy.datetime64('1986-07-13T00:00:00.000000000'),
#  numpy.datetime64('1986-07-27T00:00:00.000000000'),
#  numpy.datetime64('1986-10-08T00:00:00.000000000'),
#  numpy.datetime64('1986-08-17T00:00:00.000000000'),
#  numpy.datetime64('1986-07-09T00:00:00.000000000'),
#  numpy.datetime64('1986-09-21T00:00:00.000000000'),
#  numpy.datetime64('1986-12-10T00:00:00.000000000'),
#  numpy.datetime64('1986-10-26T00:00:00.000000000'),
#  numpy.datetime64('1985-07-04T00:00:00.000000000'),
#  numpy.datetime64('1985-04-21T00:00:00.000000000'),
#  numpy.datetime64('1985-05-05T00:00:00.000000000'),
#  numpy.datetime64('1985-05-19T00:00:00.000000000'),
#  numpy.datetime64('1985-06-16T00:00:00.000000000'),
#  numpy.datetime64('1985-06-23T00:00:00.000000000'),
#  numpy.datetime64('1985-07-07T00:00:00.000000000'),
#  numpy.datetime64('1985-07-21T00:00:00.000000000'),
#  numpy.datetime64('1985-04-08T00:00:00.000000000'),
#  numpy.datetime64('1985-08-18T00:00:00.000000000'),
#  numpy.datetime64('1985-08-25T00:00:00.000000000'),
#  numpy.datetime64('1985-08-09T00:00:00.000000000'),
#  numpy.datetime64('1985-09-15T00:00:00.000000000'),
#  numpy.datetime64('1985-06-10T00:00:00.000000000'),
#  numpy.datetime64('1985-10-19T00:00:00.000000000'),
#  numpy.datetime64('1985-03-11T00:00:00.000000000'),
#  numpy.datetime64('1984-03-25T00:00:00.000000000'),
#  numpy.datetime64('1984-07-04T00:00:00.000000000'),
#  numpy.datetime64('1984-04-29T00:00:00.000000000'),
#  numpy.datetime64('1984-06-05T00:00:00.000000000'),
#  numpy.datetime64('1984-05-20T00:00:00.000000000'),
#  numpy.datetime64('1984-03-06T00:00:00.000000000'),
#  numpy.datetime64('1984-06-17T00:00:00.000000000'),
#  numpy.datetime64('1984-06-24T00:00:00.000000000'),
#  numpy.datetime64('1984-08-07T00:00:00.000000000'),
#  numpy.datetime64('1984-07-22T00:00:00.000000000'),
#  numpy.datetime64('1984-05-08T00:00:00.000000000'),
#  numpy.datetime64('1984-08-19T00:00:00.000000000'),
#  numpy.datetime64('1984-08-26T00:00:00.000000000'),
#  numpy.datetime64('1984-09-09T00:00:00.000000000'),
#  numpy.datetime64('1984-07-10T00:00:00.000000000'),
#  numpy.datetime64('1984-10-21T00:00:00.000000000'),
#  numpy.datetime64('1983-03-13T00:00:00.000000000'),
#  numpy.datetime64('1983-03-27T00:00:00.000000000'),
#  numpy.datetime64('1983-04-17T00:00:00.000000000'),
#  numpy.datetime64('1983-01-05T00:00:00.000000000'),
#  numpy.datetime64('1983-05-15T00:00:00.000000000'),
#  numpy.datetime64('1983-05-22T00:00:00.000000000'),
#  numpy.datetime64('1983-05-06T00:00:00.000000000'),
#  numpy.datetime64('1983-12-06T00:00:00.000000000'),
#  numpy.datetime64('1983-07-16T00:00:00.000000000'),
#  numpy.datetime64('1983-07-08T00:00:00.000000000'),
#  numpy.datetime64('1983-08-14T00:00:00.000000000'),
#  numpy.datetime64('1983-08-28T00:00:00.000000000'),
#  numpy.datetime64('1983-11-09T00:00:00.000000000'),
#  numpy.datetime64('1983-09-25T00:00:00.000000000'),
#  numpy.datetime64('1983-10-15T00:00:00.000000000'),
#  numpy.datetime64('1982-01-23T00:00:00.000000000'),
#  numpy.datetime64('1982-03-21T00:00:00.000000000'),
#  numpy.datetime64('1982-04-04T00:00:00.000000000'),
#  numpy.datetime64('1982-04-25T00:00:00.000000000'),
#  numpy.datetime64('1982-09-05T00:00:00.000000000'),
#  numpy.datetime64('1982-05-23T00:00:00.000000000'),
#  numpy.datetime64('1982-06-06T00:00:00.000000000'),
#  numpy.datetime64('1982-06-13T00:00:00.000000000'),
#  numpy.datetime64('1982-03-07T00:00:00.000000000'),
#  numpy.datetime64('1982-07-18T00:00:00.000000000'),
#  numpy.datetime64('1982-07-25T00:00:00.000000000'),
#  numpy.datetime64('1982-08-08T00:00:00.000000000'),
#  numpy.datetime64('1982-08-15T00:00:00.000000000'),
#  numpy.datetime64('1982-08-29T00:00:00.000000000'),
#  numpy.datetime64('1982-12-09T00:00:00.000000000'),
#  numpy.datetime64('1982-09-25T00:00:00.000000000'),
#  numpy.datetime64('1981-03-15T00:00:00.000000000'),
#  numpy.datetime64('1981-03-29T00:00:00.000000000'),
#  numpy.datetime64('1981-12-04T00:00:00.000000000'),
#  numpy.datetime64('1981-03-05T00:00:00.000000000'),
#  numpy.datetime64('1981-05-17T00:00:00.000000000'),
#  numpy.datetime64('1981-05-31T00:00:00.000000000'),
#  numpy.datetime64('1981-06-21T00:00:00.000000000'),
#  numpy.datetime64('1981-05-07T00:00:00.000000000'),
#  numpy.datetime64('1981-07-18T00:00:00.000000000'),
#  numpy.datetime64('1981-02-08T00:00:00.000000000'),
#  numpy.datetime64('1981-08-16T00:00:00.000000000'),
#  numpy.datetime64('1981-08-30T00:00:00.000000000'),
#  numpy.datetime64('1981-09-13T00:00:00.000000000'),
#  numpy.datetime64('1981-09-27T00:00:00.000000000'),
#  numpy.datetime64('1981-10-17T00:00:00.000000000'),
#  numpy.datetime64('1980-01-13T00:00:00.000000000'),
#  numpy.datetime64('1980-01-27T00:00:00.000000000'),
#  numpy.datetime64('1980-01-03T00:00:00.000000000'),
#  numpy.datetime64('1980-03-30T00:00:00.000000000'),
#  numpy.datetime64('1980-04-05T00:00:00.000000000'),
#  numpy.datetime64('1980-05-18T00:00:00.000000000'),
#  numpy.datetime64('1980-06-29T00:00:00.000000000'),
#  numpy.datetime64('1980-07-13T00:00:00.000000000'),
#  numpy.datetime64('1980-10-08T00:00:00.000000000'),
#  numpy.datetime64('1980-08-17T00:00:00.000000000'),
#  numpy.datetime64('1980-08-31T00:00:00.000000000'),
#  numpy.datetime64('1980-09-14T00:00:00.000000000'),
#  numpy.datetime64('1980-09-28T00:00:00.000000000'),
#  numpy.datetime64('1980-05-10T00:00:00.000000000'),
#  numpy.datetime64('1979-01-21T00:00:00.000000000'),
#  numpy.datetime64('1979-04-02T00:00:00.000000000'),
#  numpy.datetime64('1979-03-03T00:00:00.000000000'),
#  numpy.datetime64('1979-08-04T00:00:00.000000000'),
#  numpy.datetime64('1979-04-29T00:00:00.000000000'),
#  numpy.datetime64('1979-05-13T00:00:00.000000000'),
#  numpy.datetime64('1979-05-27T00:00:00.000000000'),
#  numpy.datetime64('1979-01-07T00:00:00.000000000'),
#  numpy.datetime64('1979-07-14T00:00:00.000000000'),
#  numpy.datetime64('1979-07-29T00:00:00.000000000'),
#  numpy.datetime64('1979-12-08T00:00:00.000000000'),
#  numpy.datetime64('1979-08-26T00:00:00.000000000'),
#  numpy.datetime64('1979-09-09T00:00:00.000000000'),
#  numpy.datetime64('1979-09-30T00:00:00.000000000'),
#  numpy.datetime64('1979-07-10T00:00:00.000000000'),
#  numpy.datetime64('1978-01-15T00:00:00.000000000'),
#  numpy.datetime64('1978-01-29T00:00:00.000000000'),
#  numpy.datetime64('1978-04-03T00:00:00.000000000'),
#  numpy.datetime64('1978-02-04T00:00:00.000000000'),
#  numpy.datetime64('1978-07-05T00:00:00.000000000'),
#  numpy.datetime64('1978-05-21T00:00:00.000000000'),
#  numpy.datetime64('1978-04-06T00:00:00.000000000'),
#  numpy.datetime64('1978-06-17T00:00:00.000000000'),
#  numpy.datetime64('1978-02-07T00:00:00.000000000'),
#  numpy.datetime64('1978-07-16T00:00:00.000000000'),
#  numpy.datetime64('1978-07-30T00:00:00.000000000'),
#  numpy.datetime64('1978-08-13T00:00:00.000000000'),
#  numpy.datetime64('1978-08-27T00:00:00.000000000'),
#  numpy.datetime64('1978-10-09T00:00:00.000000000'),
#  numpy.datetime64('1978-01-10T00:00:00.000000000'),
#  numpy.datetime64('1978-08-10T00:00:00.000000000'),
#  numpy.datetime64('1977-09-01T00:00:00.000000000'),
#  numpy.datetime64('1977-01-23T00:00:00.000000000'),
#  numpy.datetime64('1977-05-03T00:00:00.000000000'),
#  numpy.datetime64('1977-03-04T00:00:00.000000000'),
#  numpy.datetime64('1977-08-05T00:00:00.000000000'),
#  numpy.datetime64('1977-05-22T00:00:00.000000000'),
#  numpy.datetime64('1977-05-06T00:00:00.000000000'),
#  numpy.datetime64('1977-06-19T00:00:00.000000000'),
#  numpy.datetime64('1977-03-07T00:00:00.000000000'),
#  numpy.datetime64('1977-07-16T00:00:00.000000000'),
#  numpy.datetime64('1977-07-31T00:00:00.000000000'),
#  numpy.datetime64('1977-08-14T00:00:00.000000000'),
#  numpy.datetime64('1977-08-28T00:00:00.000000000'),
#  numpy.datetime64('1977-11-09T00:00:00.000000000'),
#  numpy.datetime64('1977-02-10T00:00:00.000000000'),
#  numpy.datetime64('1977-09-10T00:00:00.000000000'),
#  numpy.datetime64('1977-10-23T00:00:00.000000000'),
#  numpy.datetime64('1976-01-25T00:00:00.000000000'),
#  numpy.datetime64('1976-06-03T00:00:00.000000000'),
#  numpy.datetime64('1976-03-28T00:00:00.000000000'),
#  numpy.datetime64('1976-02-05T00:00:00.000000000'),
#  numpy.datetime64('1976-05-16T00:00:00.000000000'),
#  numpy.datetime64('1976-05-30T00:00:00.000000000'),
#  numpy.datetime64('1976-06-13T00:00:00.000000000'),
#  numpy.datetime64('1976-04-07T00:00:00.000000000'),
#  numpy.datetime64('1976-07-18T00:00:00.000000000'),
#  numpy.datetime64('1976-01-08T00:00:00.000000000'),
#  numpy.datetime64('1976-08-15T00:00:00.000000000'),
#  numpy.datetime64('1976-08-29T00:00:00.000000000'),
#  numpy.datetime64('1976-12-09T00:00:00.000000000'),
#  numpy.datetime64('1976-03-10T00:00:00.000000000'),
#  numpy.datetime64('1976-10-10T00:00:00.000000000'),
#  numpy.datetime64('1976-10-24T00:00:00.000000000'),
#  numpy.datetime64('1975-12-01T00:00:00.000000000'),
#  numpy.datetime64('1975-01-26T00:00:00.000000000'),
#  numpy.datetime64('1975-01-03T00:00:00.000000000'),
#  numpy.datetime64('1975-04-27T00:00:00.000000000'),
#  numpy.datetime64('1975-11-05T00:00:00.000000000'),
#  numpy.datetime64('1975-05-25T00:00:00.000000000'),
#  numpy.datetime64('1975-08-06T00:00:00.000000000'),
#  numpy.datetime64('1975-06-22T00:00:00.000000000'),
#  numpy.datetime64('1975-06-07T00:00:00.000000000'),
#  numpy.datetime64('1975-07-19T00:00:00.000000000'),
#  numpy.datetime64('1975-03-08T00:00:00.000000000'),
#  numpy.datetime64('1975-08-17T00:00:00.000000000'),
#  numpy.datetime64('1975-07-09T00:00:00.000000000'),
#  numpy.datetime64('1975-05-10T00:00:00.000000000'),
#  numpy.datetime64('1974-01-13T00:00:00.000000000'),
#  numpy.datetime64('1974-01-27T00:00:00.000000000'),
#  numpy.datetime64('1974-03-30T00:00:00.000000000'),
#  numpy.datetime64('1974-04-28T00:00:00.000000000'),
#  numpy.datetime64('1974-12-05T00:00:00.000000000'),
#  numpy.datetime64('1974-05-26T00:00:00.000000000'),
#  numpy.datetime64('1974-09-06T00:00:00.000000000'),
#  numpy.datetime64('1974-06-23T00:00:00.000000000'),
#  numpy.datetime64('1974-07-07T00:00:00.000000000'),
#  numpy.datetime64('1974-07-20T00:00:00.000000000'),
#  numpy.datetime64('1974-04-08T00:00:00.000000000'),
#  numpy.datetime64('1974-08-18T00:00:00.000000000'),
#  numpy.datetime64('1974-08-09T00:00:00.000000000'),
#  numpy.datetime64('1974-09-22T00:00:00.000000000'),
#  numpy.datetime64('1974-06-10T00:00:00.000000000'),
#  numpy.datetime64('1973-01-28T00:00:00.000000000'),
#  numpy.datetime64('1973-11-02T00:00:00.000000000'),
#  numpy.datetime64('1973-03-03T00:00:00.000000000'),
#  numpy.datetime64('1973-04-29T00:00:00.000000000'),
#  numpy.datetime64('1973-05-20T00:00:00.000000000'),
#  numpy.datetime64('1973-03-06T00:00:00.000000000'),
#  numpy.datetime64('1973-06-17T00:00:00.000000000'),
#  numpy.datetime64('1973-01-07T00:00:00.000000000'),
#  numpy.datetime64('1973-07-14T00:00:00.000000000'),
#  numpy.datetime64('1973-07-29T00:00:00.000000000'),
#  numpy.datetime64('1973-05-08T00:00:00.000000000'),
#  numpy.datetime64('1973-08-19T00:00:00.000000000'),
#  numpy.datetime64('1973-09-09T00:00:00.000000000'),
#  numpy.datetime64('1973-09-23T00:00:00.000000000'),
#  numpy.datetime64('1973-07-10T00:00:00.000000000'),
#  numpy.datetime64('2072-01-23T00:00:00.000000000'),
#  numpy.datetime64('2072-04-03T00:00:00.000000000'),
#  numpy.datetime64('2072-01-05T00:00:00.000000000'),
#  numpy.datetime64('2072-05-14T00:00:00.000000000'),
#  numpy.datetime64('2072-04-06T00:00:00.000000000'),
#  numpy.datetime64('2072-02-07T00:00:00.000000000'),
#  numpy.datetime64('2072-07-15T00:00:00.000000000'),
#  numpy.datetime64('2072-07-30T00:00:00.000000000'),
#  numpy.datetime64('2072-08-13T00:00:00.000000000'),
#  numpy.datetime64('2072-10-09T00:00:00.000000000'),
#  numpy.datetime64('2072-09-24T00:00:00.000000000'),
#  numpy.datetime64('2072-08-10T00:00:00.000000000'),
#  numpy.datetime64('2071-06-03T00:00:00.000000000'),
#  numpy.datetime64('2071-04-18T00:00:00.000000000'),
#  numpy.datetime64('2071-05-23T00:00:00.000000000'),
#  numpy.datetime64('2071-06-20T00:00:00.000000000'),
#  numpy.datetime64('2071-04-07T00:00:00.000000000'),
#  numpy.datetime64('2071-07-17T00:00:00.000000000'),
#  numpy.datetime64('2071-01-08T00:00:00.000000000'),
#  numpy.datetime64('2071-08-15T00:00:00.000000000'),
#  numpy.datetime64('2071-05-09T00:00:00.000000000'),
#  numpy.datetime64('2071-09-19T00:00:00.000000000'),
#  numpy.datetime64('2071-03-10T00:00:00.000000000'),
#  numpy.datetime64('2070-07-03T00:00:00.000000000'),
#  numpy.datetime64('2070-04-19T00:00:00.000000000'),
#  numpy.datetime64('2070-10-05T00:00:00.000000000'),
#  numpy.datetime64('2070-07-06T00:00:00.000000000'),
#  numpy.datetime64('2070-06-21T00:00:00.000000000'),
#  numpy.datetime64('2070-05-07T00:00:00.000000000'),
#  numpy.datetime64('2070-07-18T00:00:00.000000000'),
#  numpy.datetime64('2070-02-08T00:00:00.000000000'),
#  numpy.datetime64('2070-08-16T00:00:00.000000000'),
#  numpy.datetime64('2070-06-09T00:00:00.000000000'),
#  numpy.datetime64('2070-09-20T00:00:00.000000000'),
#  numpy.datetime64('2070-04-10T00:00:00.000000000'),
#  numpy.datetime64('2070-10-25T00:00:00.000000000'),
#  numpy.datetime64('2069-01-03T00:00:00.000000000'),
#  numpy.datetime64('2069-04-05T00:00:00.000000000'),
#  numpy.datetime64('2069-05-18T00:00:00.000000000'),
#  numpy.datetime64('2069-06-21T00:00:00.000000000'),
#  numpy.datetime64('2069-06-07T00:00:00.000000000'),
#  numpy.datetime64('2069-07-19T00:00:00.000000000'),
#  numpy.datetime64('2069-03-08T00:00:00.000000000'),
#  numpy.datetime64('2069-07-09T00:00:00.000000000'),
#  numpy.datetime64('2069-09-20T00:00:00.000000000'),
#  numpy.datetime64('2069-05-10T00:00:00.000000000'),
#  numpy.datetime64('2069-10-19T00:00:00.000000000'),
#  numpy.datetime64('2068-01-01T00:00:00.000000000'),
#  numpy.datetime64('2068-12-05T00:00:00.000000000'),
#  numpy.datetime64('2068-05-26T00:00:00.000000000'),
#  numpy.datetime64('2068-09-06T00:00:00.000000000'),
#  numpy.datetime64('2068-06-23T00:00:00.000000000'),
#  numpy.datetime64('2068-07-07T00:00:00.000000000'),
#  numpy.datetime64('2068-07-20T00:00:00.000000000'),
#  numpy.datetime64('2068-04-08T00:00:00.000000000'),
#  numpy.datetime64('2068-08-09T00:00:00.000000000'),
#  numpy.datetime64('2068-09-22T00:00:00.000000000'),
#  numpy.datetime64('2068-06-10T00:00:00.000000000'),
#  numpy.datetime64('2068-03-11T00:00:00.000000000'),
#  numpy.datetime64('2067-02-01T00:00:00.000000000'),
#  numpy.datetime64('2067-07-05T00:00:00.000000000'),
#  numpy.datetime64('2067-04-06T00:00:00.000000000'),
#  numpy.datetime64('2067-06-18T00:00:00.000000000'),
#  numpy.datetime64('2067-02-07T00:00:00.000000000'),
#  numpy.datetime64('2067-07-15T00:00:00.000000000'),
#  numpy.datetime64('2067-06-08T00:00:00.000000000'),
#  numpy.datetime64('2067-08-27T00:00:00.000000000'),
#  numpy.datetime64('2067-10-09T00:00:00.000000000'),
#  numpy.datetime64('2067-01-10T00:00:00.000000000'),
#  numpy.datetime64('2067-10-22T00:00:00.000000000'),
#  numpy.datetime64('2066-05-22T00:00:00.000000000'),
#  numpy.datetime64('2066-12-06T00:00:00.000000000'),
#  numpy.datetime64('2066-03-07T00:00:00.000000000'),
#  numpy.datetime64('2066-07-16T00:00:00.000000000'),
#  numpy.datetime64('2066-07-24T00:00:00.000000000'),
#  numpy.datetime64('2066-07-08T00:00:00.000000000'),
#  numpy.datetime64('2066-04-09T00:00:00.000000000'),
#  numpy.datetime64('2066-02-10T00:00:00.000000000'),
#  numpy.datetime64('2066-10-23T00:00:00.000000000'),
#  numpy.datetime64('2065-01-01T00:00:00.000000000'),
#  numpy.datetime64('2065-05-30T00:00:00.000000000'),
#  numpy.datetime64('2065-06-13T00:00:00.000000000'),
#  numpy.datetime64('2065-06-27T00:00:00.000000000'),
#  numpy.datetime64('2065-10-07T00:00:00.000000000'),
#  numpy.datetime64('2065-07-18T00:00:00.000000000'),
#  numpy.datetime64('2065-01-08T00:00:00.000000000'),
#  numpy.datetime64('2065-12-09T00:00:00.000000000'),
#  numpy.datetime64('2065-03-10T00:00:00.000000000'),
#  numpy.datetime64('2065-10-24T00:00:00.000000000'),
#  numpy.datetime64('2064-10-05T00:00:00.000000000'),
#  numpy.datetime64('2064-05-24T00:00:00.000000000'),
#  numpy.datetime64('2064-06-14T00:00:00.000000000'),
#  numpy.datetime64('2064-06-28T00:00:00.000000000'),
#  numpy.datetime64('2064-11-07T00:00:00.000000000'),
#  numpy.datetime64('2064-02-08T00:00:00.000000000'),
#  numpy.datetime64('2064-08-23T00:00:00.000000000'),
#  numpy.datetime64('2064-06-09T00:00:00.000000000'),
#  numpy.datetime64('2064-04-10T00:00:00.000000000'),
#  numpy.datetime64('2064-10-25T00:00:00.000000000'),
#  numpy.datetime64('2063-05-26T00:00:00.000000000'),
#  numpy.datetime64('2063-09-06T00:00:00.000000000'),
#  numpy.datetime64('2063-06-23T00:00:00.000000000'),
#  numpy.datetime64('2063-06-30T00:00:00.000000000'),
#  numpy.datetime64('2063-07-20T00:00:00.000000000'),
#  numpy.datetime64('2063-04-08T00:00:00.000000000'),
#  numpy.datetime64('2063-08-09T00:00:00.000000000'),
#  numpy.datetime64('2063-06-10T00:00:00.000000000'),
#  numpy.datetime64('2063-10-27T00:00:00.000000000'),
#  numpy.datetime64('2063-12-28T00:00:00.000000000'),
#  numpy.datetime64('2062-05-20T00:00:00.000000000'),
#  numpy.datetime64('2062-03-06T00:00:00.000000000'),
#  numpy.datetime64('2062-06-17T00:00:00.000000000'),
#  numpy.datetime64('2062-08-07T00:00:00.000000000'),
#  numpy.datetime64('2062-07-21T00:00:00.000000000'),
#  numpy.datetime64('2062-05-08T00:00:00.000000000'),
#  numpy.datetime64('2062-09-16T00:00:00.000000000'),
#  numpy.datetime64('2062-07-10T00:00:00.000000000'),
#  numpy.datetime64('2062-12-29T00:00:00.000000000'),
#  numpy.datetime64('2061-05-14T00:00:00.000000000'),
#  numpy.datetime64('2061-05-22T00:00:00.000000000'),
#  numpy.datetime64('2061-06-18T00:00:00.000000000'),
#  numpy.datetime64('2061-02-07T00:00:00.000000000'),
#  numpy.datetime64('2061-07-15T00:00:00.000000000'),
#  numpy.datetime64('2061-06-08T00:00:00.000000000'),
#  numpy.datetime64('2061-10-09T00:00:00.000000000'),
#  numpy.datetime64('2061-08-10T00:00:00.000000000'),
#  numpy.datetime64('2060-07-02T00:00:00.000000000'),
#  numpy.datetime64('2060-05-29T00:00:00.000000000'),
#  numpy.datetime64('2060-05-30T00:00:00.000000000'),
#  numpy.datetime64('2060-06-06T00:00:00.000000000'),
#  numpy.datetime64('2060-06-19T00:00:00.000000000'),
#  numpy.datetime64('2060-03-07T00:00:00.000000000'),
#  numpy.datetime64('2060-07-16T00:00:00.000000000'),
#  numpy.datetime64('2060-08-14T00:00:00.000000000'),
#  numpy.datetime64('2060-04-09T00:00:00.000000000'),
#  numpy.datetime64('2060-11-20T00:00:00.000000000'),
#  numpy.datetime64('2059-10-05T00:00:00.000000000'),
#  numpy.datetime64('2059-05-30T00:00:00.000000000'),
#  numpy.datetime64('2059-05-31T00:00:00.000000000'),
#  numpy.datetime64('2059-05-07T00:00:00.000000000'),
#  numpy.datetime64('2059-07-18T00:00:00.000000000'),
#  numpy.datetime64('2059-02-08T00:00:00.000000000'),
#  numpy.datetime64('2059-08-23T00:00:00.000000000'),
#  numpy.datetime64('2059-09-13T00:00:00.000000000'),
#  numpy.datetime64('2059-12-12T00:00:00.000000000'),
#  numpy.datetime64('2058-01-19T00:00:00.000000000'),
#  numpy.datetime64('2058-05-18T00:00:00.000000000'),
#  numpy.datetime64('2058-05-26T00:00:00.000000000'),
#  numpy.datetime64('2058-05-30T00:00:00.000000000'),
#  numpy.datetime64('2058-06-15T00:00:00.000000000'),
#  numpy.datetime64('2058-06-07T00:00:00.000000000'),
#  numpy.datetime64('2058-07-19T00:00:00.000000000'),
#  numpy.datetime64('2058-03-08T00:00:00.000000000'),
#  numpy.datetime64('2058-08-24T00:00:00.000000000'),
#  numpy.datetime64('2058-07-09T00:00:00.000000000'),
#  numpy.datetime64('2058-10-19T00:00:00.000000000'),
#  numpy.datetime64('2057-01-13T00:00:00.000000000'),
#  numpy.datetime64('2057-05-19T00:00:00.000000000'),
#  numpy.datetime64('2057-05-30T00:00:00.000000000'),
#  numpy.datetime64('2057-07-07T00:00:00.000000000'),
#  numpy.datetime64('2057-07-20T00:00:00.000000000'),
#  numpy.datetime64('2057-04-08T00:00:00.000000000'),
#  numpy.datetime64('2057-08-18T00:00:00.000000000'),
#  numpy.datetime64('2057-08-09T00:00:00.000000000'),
#  numpy.datetime64('2056-01-22T00:00:00.000000000'),
#  numpy.datetime64('2056-05-13T00:00:00.000000000'),
#  numpy.datetime64('2056-05-30T00:00:00.000000000'),
#  numpy.datetime64('2056-03-06T00:00:00.000000000'),
#  numpy.datetime64('2056-01-07T00:00:00.000000000'),
#  numpy.datetime64('2056-07-14T00:00:00.000000000'),
#  numpy.datetime64('2056-05-08T00:00:00.000000000'),
#  numpy.datetime64('2056-02-09T00:00:00.000000000'),
#  numpy.datetime64('2055-01-16T00:00:00.000000000'),
#  numpy.datetime64('2055-05-22T00:00:00.000000000'),
#  numpy.datetime64('2055-05-30T00:00:00.000000000'),
#  numpy.datetime64('2055-05-06T00:00:00.000000000'),
#  numpy.datetime64('2055-06-19T00:00:00.000000000'),
#  numpy.datetime64('2055-07-16T00:00:00.000000000'),
#  numpy.datetime64('2055-11-09T00:00:00.000000000'),
#  numpy.datetime64('2054-01-17T00:00:00.000000000'),
#  numpy.datetime64('2054-05-31T00:00:00.000000000'),
#  numpy.datetime64('2054-06-20T00:00:00.000000000'),
#  numpy.datetime64('2054-04-07T00:00:00.000000000'),
#  numpy.datetime64('2054-07-17T00:00:00.000000000'),
#  numpy.datetime64('2054-01-08T00:00:00.000000000'),
#  numpy.datetime64('2054-08-22T00:00:00.000000000'),
#  numpy.datetime64('2054-05-09T00:00:00.000000000'),
#  numpy.datetime64('2054-10-24T00:00:00.000000000'),
#  numpy.datetime64('2053-01-18T00:00:00.000000000'),
#  numpy.datetime64('2053-05-30T00:00:00.000000000'),
#  numpy.datetime64('2053-07-06T00:00:00.000000000'),
#  numpy.datetime64('2053-06-21T00:00:00.000000000'),
#  numpy.datetime64('2053-05-07T00:00:00.000000000'),
#  numpy.datetime64('2053-07-18T00:00:00.000000000'),
#  numpy.datetime64('2053-02-08T00:00:00.000000000'),
#  numpy.datetime64('2053-08-23T00:00:00.000000000'),
#  numpy.datetime64('2053-09-13T00:00:00.000000000'),
#  numpy.datetime64('2052-05-18T00:00:00.000000000'),
#  numpy.datetime64('2052-05-30T00:00:00.000000000'),
#  numpy.datetime64('2052-06-22T00:00:00.000000000'),
#  numpy.datetime64('2052-06-07T00:00:00.000000000'),
#  numpy.datetime64('2052-07-19T00:00:00.000000000'),
#  numpy.datetime64('2052-03-08T00:00:00.000000000'),
#  numpy.datetime64('2052-08-17T00:00:00.000000000'),
#  numpy.datetime64('2052-07-09T00:00:00.000000000'),
#  numpy.datetime64('2051-05-27T00:00:00.000000000'),
#  numpy.datetime64('2051-05-30T00:00:00.000000000'),
#  numpy.datetime64('2051-06-17T00:00:00.000000000'),
#  numpy.datetime64('2051-01-07T00:00:00.000000000'),
#  numpy.datetime64('2051-07-14T00:00:00.000000000'),
#  numpy.datetime64('2051-07-29T00:00:00.000000000'),
#  numpy.datetime64('2051-09-16T00:00:00.000000000'),
#  numpy.datetime64('2051-10-28T00:00:00.000000000'),
#  numpy.datetime64('2050-05-13T00:00:00.000000000'),
#  numpy.datetime64('2050-05-21T00:00:00.000000000'),
#  numpy.datetime64('2050-05-30T00:00:00.000000000'),
#  numpy.datetime64('2050-04-06T00:00:00.000000000'),
#  numpy.datetime64('2050-06-18T00:00:00.000000000'),
#  numpy.datetime64('2050-02-07T00:00:00.000000000'),
#  numpy.datetime64('2050-03-09T00:00:00.000000000'),
#  numpy.datetime64('2011-03-27T00:00:00.000000000'),
#  numpy.datetime64('2011-10-04T00:00:00.000000000'),
#  numpy.datetime64('2011-04-17T00:00:00.000000000'),
#  numpy.datetime64('2011-08-05T00:00:00.000000000'),
#  numpy.datetime64('2011-05-22T00:00:00.000000000'),
#  numpy.datetime64('2011-05-29T00:00:00.000000000'),
#  numpy.datetime64('2011-12-06T00:00:00.000000000'),
#  numpy.datetime64('2011-06-26T00:00:00.000000000'),
#  numpy.datetime64('2011-10-07T00:00:00.000000000'),
#  numpy.datetime64('2011-07-24T00:00:00.000000000'),
#  numpy.datetime64('2011-07-31T00:00:00.000000000'),
#  numpy.datetime64('2011-08-28T00:00:00.000000000'),
#  numpy.datetime64('2011-11-09T00:00:00.000000000'),
#  numpy.datetime64('2011-09-25T00:00:00.000000000'),
#  numpy.datetime64('2011-09-10T00:00:00.000000000'),
#  numpy.datetime64('2011-10-16T00:00:00.000000000'),
#  numpy.datetime64('2011-10-30T00:00:00.000000000'),
#  numpy.datetime64('2011-11-13T00:00:00.000000000'),
#  numpy.datetime64('2011-11-27T00:00:00.000000000'),
#  numpy.datetime64('2012-03-18T00:00:00.000000000'),
#  numpy.datetime64('2012-03-25T00:00:00.000000000'),
#  numpy.datetime64('2012-04-15T00:00:00.000000000'),
#  numpy.datetime64('2012-04-22T00:00:00.000000000'),
#  numpy.datetime64('2012-05-13T00:00:00.000000000'),
#  numpy.datetime64('2012-05-27T00:00:00.000000000'),
#  numpy.datetime64('2012-10-06T00:00:00.000000000'),
#  numpy.datetime64('2012-06-24T00:00:00.000000000'),
#  numpy.datetime64('2012-08-07T00:00:00.000000000'),
#  numpy.datetime64('2012-07-22T00:00:00.000000000'),
#  numpy.datetime64('2012-07-29T00:00:00.000000000'),
#  numpy.datetime64('2012-02-09T00:00:00.000000000'),
#  numpy.datetime64('2012-09-09T00:00:00.000000000'),
#  numpy.datetime64('2012-09-23T00:00:00.000000000'),
#  numpy.datetime64('2012-07-10T00:00:00.000000000'),
#  numpy.datetime64('2012-10-14T00:00:00.000000000'),
#  numpy.datetime64('2012-10-28T00:00:00.000000000'),
#  numpy.datetime64('2012-04-11T00:00:00.000000000'),
#  numpy.datetime64('2012-11-18T00:00:00.000000000'),
#  numpy.datetime64('2012-11-25T00:00:00.000000000'),
#  numpy.datetime64('2013-03-17T00:00:00.000000000'),
#  numpy.datetime64('2013-03-24T00:00:00.000000000'),
#  numpy.datetime64('2013-04-14T00:00:00.000000000'),
#  numpy.datetime64('2013-04-21T00:00:00.000000000'),
#  numpy.datetime64('2013-12-05T00:00:00.000000000'),
#  numpy.datetime64('2013-05-26T00:00:00.000000000'),
#  numpy.datetime64('2013-09-06T00:00:00.000000000'),
#  numpy.datetime64('2013-06-30T00:00:00.000000000'),
#  numpy.datetime64('2013-07-07T00:00:00.000000000'),
#  numpy.datetime64('2013-07-28T00:00:00.000000000'),
#  numpy.datetime64('2013-08-25T00:00:00.000000000'),
#  numpy.datetime64('2013-08-09T00:00:00.000000000'),
#  numpy.datetime64('2013-09-22T00:00:00.000000000'),
#  numpy.datetime64('2013-06-10T00:00:00.000000000'),
#  numpy.datetime64('2013-10-13T00:00:00.000000000'),
#  numpy.datetime64('2013-10-27T00:00:00.000000000'),
#  numpy.datetime64('2013-03-11T00:00:00.000000000'),
#  numpy.datetime64('2013-11-17T00:00:00.000000000'),
#  numpy.datetime64('2013-11-24T00:00:00.000000000'),
#  numpy.datetime64('2014-03-16T00:00:00.000000000'),
#  numpy.datetime64('2014-03-30T00:00:00.000000000'),
#  numpy.datetime64('2014-06-04T00:00:00.000000000'),
#  numpy.datetime64('2014-04-20T00:00:00.000000000'),
#  numpy.datetime64('2014-11-05T00:00:00.000000000'),
#  numpy.datetime64('2014-05-25T00:00:00.000000000'),
#  numpy.datetime64('2014-08-06T00:00:00.000000000'),
#  numpy.datetime64('2014-06-22T00:00:00.000000000'),
#  numpy.datetime64('2014-06-07T00:00:00.000000000'),
#  numpy.datetime64('2014-07-20T00:00:00.000000000'),
#  numpy.datetime64('2014-07-27T00:00:00.000000000'),
#  numpy.datetime64('2014-08-24T00:00:00.000000000'),
#  numpy.datetime64('2014-07-09T00:00:00.000000000'),
#  numpy.datetime64('2014-09-21T00:00:00.000000000'),
#  numpy.datetime64('2014-05-10T00:00:00.000000000'),
#  numpy.datetime64('2014-12-10T00:00:00.000000000'),
#  numpy.datetime64('2014-02-11T00:00:00.000000000'),
#  numpy.datetime64('2014-09-11T00:00:00.000000000'),
#  numpy.datetime64('2014-11-23T00:00:00.000000000'),
#  numpy.datetime64('2015-05-24T00:00:00.000000000'),
#  numpy.datetime64('2015-07-06T00:00:00.000000000'),
#  numpy.datetime64('2015-04-19T00:00:00.000000000'),
#  numpy.datetime64('2015-10-05T00:00:00.000000000'),
#  numpy.datetime64('2015-12-04T00:00:00.000000000'),
#  numpy.datetime64('2015-03-15T00:00:00.000000000'),
#  numpy.datetime64('2015-03-29T00:00:00.000000000'),
#  numpy.datetime64('2015-06-21T00:00:00.000000000'),
#  numpy.datetime64('2015-05-07T00:00:00.000000000'),
#  numpy.datetime64('2015-07-26T00:00:00.000000000'),
#  numpy.datetime64('2015-08-23T00:00:00.000000000'),
#  numpy.datetime64('2015-06-09T00:00:00.000000000'),
#  numpy.datetime64('2015-09-20T00:00:00.000000000'),
#  numpy.datetime64('2015-09-27T00:00:00.000000000'),
#  numpy.datetime64('2015-11-10T00:00:00.000000000'),
#  numpy.datetime64('2015-10-25T00:00:00.000000000'),
#  numpy.datetime64('2015-01-11T00:00:00.000000000'),
#  numpy.datetime64('2015-11-15T00:00:00.000000000'),
#  numpy.datetime64('2015-11-29T00:00:00.000000000'),
#  numpy.datetime64('2016-03-20T00:00:00.000000000'),
#  numpy.datetime64('2016-03-04T00:00:00.000000000'),
#  numpy.datetime64('2016-04-17T00:00:00.000000000'),
#  numpy.datetime64('2016-01-05T00:00:00.000000000'),
#  numpy.datetime64('2016-05-15T00:00:00.000000000'),
#  numpy.datetime64('2016-05-29T00:00:00.000000000'),
#  numpy.datetime64('2016-12-06T00:00:00.000000000'),
#  numpy.datetime64('2016-06-19T00:00:00.000000000'),
#  numpy.datetime64('2016-03-07T00:00:00.000000000'),
#  numpy.datetime64('2016-10-07T00:00:00.000000000'),
#  numpy.datetime64('2016-07-24T00:00:00.000000000'),
#  numpy.datetime64('2016-07-31T00:00:00.000000000'),
#  numpy.datetime64('2016-08-28T00:00:00.000000000'),
#  numpy.datetime64('2016-04-09T00:00:00.000000000'),
#  numpy.datetime64('2016-09-18T00:00:00.000000000'),
#  numpy.datetime64('2016-02-10T00:00:00.000000000'),
#  numpy.datetime64('2016-09-10T00:00:00.000000000'),
#  numpy.datetime64('2016-10-23T00:00:00.000000000'),
#  numpy.datetime64('2016-10-30T00:00:00.000000000'),
#  numpy.datetime64('2016-11-13T00:00:00.000000000'),
#  numpy.datetime64('2016-11-27T00:00:00.000000000'),
#  numpy.datetime64('2017-03-26T00:00:00.000000000'),
#  numpy.datetime64('2017-09-04T00:00:00.000000000'),
#  numpy.datetime64('2017-04-16T00:00:00.000000000'),
#  numpy.datetime64('2017-04-30T00:00:00.000000000'),
#  numpy.datetime64('2017-05-14T00:00:00.000000000'),
#  numpy.datetime64('2017-05-28T00:00:00.000000000'),
#  numpy.datetime64('2017-11-06T00:00:00.000000000'),
#  numpy.datetime64('2017-06-25T00:00:00.000000000'),
#  numpy.datetime64('2017-09-07T00:00:00.000000000'),
#  numpy.datetime64('2017-07-16T00:00:00.000000000'),
#  numpy.datetime64('2017-07-30T00:00:00.000000000'),
#  numpy.datetime64('2017-08-27T00:00:00.000000000'),
#  numpy.datetime64('2017-03-09T00:00:00.000000000'),
#  numpy.datetime64('2017-09-17T00:00:00.000000000'),
#  numpy.datetime64('2017-01-10T00:00:00.000000000'),
#  numpy.datetime64('2017-08-10T00:00:00.000000000'),
#  numpy.datetime64('2017-10-22T00:00:00.000000000'),
#  numpy.datetime64('2017-10-29T00:00:00.000000000'),
#  numpy.datetime64('2017-12-11T00:00:00.000000000'),
#  numpy.datetime64('2017-11-26T00:00:00.000000000'),
#  numpy.datetime64('2018-03-25T00:00:00.000000000'),
#  numpy.datetime64('2018-08-04T00:00:00.000000000'),
#  numpy.datetime64('2018-04-15T00:00:00.000000000'),
#  numpy.datetime64('2018-04-29T00:00:00.000000000'),
#  numpy.datetime64('2018-05-13T00:00:00.000000000'),
#  numpy.datetime64('2018-05-27T00:00:00.000000000'),
#  numpy.datetime64('2018-10-06T00:00:00.000000000'),
#  numpy.datetime64('2018-06-24T00:00:00.000000000'),
#  numpy.datetime64('2018-01-07T00:00:00.000000000'),
#  numpy.datetime64('2018-08-07T00:00:00.000000000'),
#  numpy.datetime64('2018-07-22T00:00:00.000000000'),
#  numpy.datetime64('2018-07-29T00:00:00.000000000'),
#  numpy.datetime64('2018-08-26T00:00:00.000000000'),
#  numpy.datetime64('2018-02-09T00:00:00.000000000'),
#  numpy.datetime64('2018-09-16T00:00:00.000000000'),
#  numpy.datetime64('2018-09-30T00:00:00.000000000'),
#  numpy.datetime64('2018-07-10T00:00:00.000000000'),
#  numpy.datetime64('2018-10-21T00:00:00.000000000'),
#  numpy.datetime64('2018-10-28T00:00:00.000000000'),
#  numpy.datetime64('2018-11-11T00:00:00.000000000'),
#  numpy.datetime64('2018-11-25T00:00:00.000000000'),
#  numpy.datetime64('2019-03-17T00:00:00.000000000'),
#  numpy.datetime64('2019-03-31T00:00:00.000000000'),
#  numpy.datetime64('2019-04-14T00:00:00.000000000'),
#  ...]

# %%
result_races.head(1)
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
#
#   positionText  positionOrder  points  ...  fastestLapTime fastestLapSpeed  \
# 0            1              1    10.0  ...        1:27.452           218.3
#
#    statusId  year  round circuitId                   name       date  \
# 0         1  2008      1         1  Australian Grand Prix 2008-03-16
#
#      time_y                                                url
# 0  04:30:00  http://en.wikipedia.org/wiki/2008_Australian_G...
#
# [1 rows x 25 columns]

# %%
result_races['date'].max()
# Out:
# Timestamp('2022-04-10 00:00:00')

# %%
pd.set_option('display.max_columns',30)

pd.set_option('display.max_rows',500)

result_races[(result_races['date'].dt.year >= 1950) & (result_races['date'].dt.year < 1951)]
# Out:
#        resultId  raceId  driverId  constructorId  number  grid  position  \
# 20140     20025     833       642             51     2.0     1       1.0
# 20141     20026     833       786             51     3.0     2       2.0
# 20142     20027     833       686             51     4.0     4       3.0
# 20143     20028     833       704            154    14.0     6       4.0
# 20144     20029     833       627            154    15.0     9       5.0
# 20145     20030     833       619            151    12.0    13       6.0
# 20146     20031     833       787            151    11.0    15       7.0
# 20147     20032     833       741            154    16.0    14       8.0
# 20148     20033     833       784            105     6.0    16       9.0
# 20149     20034     833       778            105    10.0    20      10.0
# 20150     20035     833       660            154    18.0    21      11.0
# 20151     20036     833       579             51     1.0     3       NaN
# 20152     20037     833       776            126    23.0    19       NaN
# 20153     20038     833       669            105    21.0     5       NaN
# 20154     20039     833       747            105     5.0    18       NaN
# 20155     20040     833       785            126    24.0    17       NaN
# 20156     20041     833       640            105    20.0     8       NaN
# 20157     20042     833       589            105    19.0    11       NaN
# 20158     20043     833       789            154    17.0     7       NaN
# 20159     20044     833       661            151     9.0    10       NaN
# 20160     20045     833       790            151     8.0    12       NaN
# 20161     20177     833       788            105    10.0    20      10.0
# 20162     20178     833       666            151     9.0    10       NaN
# 20163     20046     834       579             51    34.0     1       1.0
# 20164     20047     834       647              6    40.0     7       2.0
# 20165     20048     834       589            105    48.0     8       3.0
# 20166     20049     834       793              6    42.0     9       4.0
# 20167     20050     834       669            105    50.0    15       5.0
# 20168     20051     834       619            151    26.0    16       6.0
# 20169     20052     834       660            154     6.0    19       7.0
# 20170     20053     834       633              6    38.0     6       NaN
# 20171     20054     834       741            154    14.0     4       NaN
# 20172     20055     834       498            105     2.0     3       NaN
# 20173     20056     834       642             51    32.0     2       NaN
# 20174     20057     834       786             51    36.0     5       NaN
# 20175     20058     834       627            154    16.0    10       NaN
# 20176     20059     834       626            141    10.0    11       NaN
# 20177     20060     834       640            105    52.0    12       NaN
# 20178     20061     834       427            141    12.0    13       NaN
# 20179     20062     834       787            151    24.0    14       NaN
# 20180     20063     834       762            105    44.0    17       NaN
# 20181     20064     834       501             87     8.0    20       NaN
# 20182     20065     834       687              6    28.0    21       NaN
# 20183     20066     834       792            105     4.0    18       NaN
# 20184     20067     835       593            113     1.0     5       1.0
# 20185     20068     835       701            150     3.0    10       2.0
# 20186     20069     835       768            150    31.0     3       3.0
# 20187     20070     835       770            113    54.0    12       4.0
# 20188     20071     835       794            113    17.0     9       5.0
# 20189     20072     835       766            119     8.0    23       6.0
# 20190     20073     835       654            113    98.0     1       7.0
# 20191     20074     835       726            110     5.0     4       8.0
# 20192     20075     835       555            138     7.0    19       9.0
# 20193     20076     835       559            113    59.0    11      10.0
# 20194     20077     835       795            156     2.0    16      11.0
# 20195     20078     835       518            129    18.0    13      12.0
# 20196     20079     835       772            113    15.0    26      13.0
# 20197     20080     835       658            113    49.0     6      14.0
# 20198     20081     835       526            110    55.0    24      15.0
# 20199     20082     835       520            157    75.0    31      16.0
# 20200     20083     835       653            116    22.0    27      17.0
# 20201     20084     835       732            113    62.0    33      18.0
# 20202     20085     835       771            113     4.0    20      19.0
# 20203     20086     835       677            105    21.0    14      20.0
# 20204     20087     835       659            113    81.0    15      21.0
# 20205     20088     835       796            158    27.0    29      22.0
# 20206     20089     835       797            159    77.0    30      23.0
# 20207     20090     835       509            160    76.0    28      24.0
# 20208     20091     835       731            105    12.0    21       NaN
# 20209     20092     835       729            162    67.0    22       NaN
# 20210     20093     835       798            161    24.0    17       NaN
# 20211     20094     835       615            113    28.0     2       NaN
# 20212     20095     835       799            113    61.0    32       NaN
# 20213     20096     835       611            113    23.0    25       NaN
# 20214     20097     835       529            150    14.0     8       NaN
# 20215     20098     835       537            107    45.0    18       NaN
# 20216     20099     835       630            113    69.0     7       NaN
# 20217     20179     835       529            113    17.0     9       5.0
# 20218     20180     835       803            161    24.0    17       NaN
# 20219     20100     836       642             51    16.0     2       1.0
# 20220     20101     836       786             51    12.0     3       2.0
# 20221     20102     836       627            154    10.0    10       3.0
# 20222     20103     836       669            105    30.0     8       4.0
# 20223     20104     836       697            105    34.0    12       5.0
# 20224     20105     836       640            105    32.0    11       6.0
# 20225     20106     836       800            105     2.0    15       7.0
# 20226     20107     836       501            154    44.0    18       8.0
# 20227     20108     836       589            105    26.0    16       9.0
# 20228     20109     836       660            154     4.0    14      10.0
# 20229     20110     836       780            105    40.0    17      11.0
# 20230     20111     836       579             51    14.0     1       NaN
# 20231     20112     836       741            154    42.0     6       NaN
# 20232     20113     836       789            154     8.0     9       NaN
# 20233     20114     836       793              6    20.0    13       NaN
# 20234     20115     836       633              6    22.0     4       NaN
# 20235     20116     836       647              6    18.0     5       NaN
# 20236     20117     836       704            154     6.0     7       NaN
# 20237     20118     837       579             51    10.0     2       1.0
# 20238     20119     837       786             51    12.0     3       2.0
# 20239     20120     837       627            154    14.0     8       3.0
# 20240     20121     837       642             51     8.0     1       4.0
# 20241     20122     837       647              6     4.0     7       5.0
# 20242     20123     837       633              6     2.0     4       6.0
# 20243     20124     837       773            154    22.0    10       7.0
# 20244     20125     837       660            154    24.0    14       8.0
# 20245     20126     837       785            126    26.0    12       9.0
# 20246     20127     837       780            105    30.0    11      10.0
# 20247     20128     837       774            154    20.0    13       NaN
# 20248     20129     837       793            154     6.0     5       NaN
# 20249     20130     837       741            154    16.0     6       NaN
# 20250     20131     837       704            154    18.0     9       NaN
# 20251     20132     838       579             51     6.0     1       1.0
# 20252     20133     838       786             51     4.0     3       2.0
# 20253     20134     838       687              6    14.0    18       3.0
# 20254     20135     838       626            141    44.0    12       4.0
# 20255     20136     838       741            154    16.0     4       5.0
# 20256     20137     838       801            154    26.0    15       6.0
# 20257     20138     838       642             51     2.0     2       7.0
# 20258     20139     838       704            154    18.0     5       8.0
# 20259     20140     838       773            154    22.0     9       NaN
# 20260     20141     838       697            105    40.0    10       NaN
# 20261     20142     838       660            154    42.0    14       NaN
# 20262     20143     838       627            154    20.0     6       NaN
# 20263     20144     838       686            105    32.0    11       NaN
# 20264     20145     838       762            105    28.0     7       NaN
# 20265     20146     838       589            105    30.0    13       NaN
# 20266     20147     838       784            105    34.0    17       NaN
# 20267     20148     838       793            154    12.0    16       NaN
# 20268     20149     838       498            105    36.0     8       NaN
# 20269     20181     838       774            154    16.0     4       5.0
# 20270     20182     838       627            154    26.0    15       6.0
# 20271     20150     839       642             51    10.0     3       1.0
# 20272     20151     839       802              6    48.0     6       2.0
# 20273     20152     839       786             51    36.0     5       3.0
# 20274     20153     839       627            154    58.0    13       4.0
# 20275     20154     839       741            154    24.0    16       5.0
# 20276     20155     839       640            105    38.0    17       6.0
# 20277     20156     839       687              6     8.0    18       7.0
# 20278     20157     839       747            105    50.0    24       NaN
# 20279     20158     839       787            151    32.0    21       NaN
# 20280     20159     839       793            154    12.0     8       NaN
# 20281     20160     839       764            154    40.0    11       NaN
# 20282     20161     839       762            105     4.0     9       NaN
# 20283     20162     839       641             51    60.0     7       NaN
# 20284     20163     839       773            154    56.0    20       NaN
# 20285     20164     839       579             51    18.0     1       NaN
# 20286     20165     839       660            154     2.0    22       NaN
# 20287     20166     839       647              6    16.0     2       NaN
# 20288     20167     839       791              6    22.0    25       NaN
# 20289     20168     839       765            154    64.0    16       NaN
# 20290     20169     839       740            105    62.0    26       NaN
# 20291     20170     839       427            141    42.0    12       NaN
# 20292     20171     839       589            105     6.0    19       NaN
# 20293     20172     839       763             51    46.0     4       NaN
# 20294     20173     839       626            141    44.0    10       NaN
# 20295     20174     839       669            105    30.0    15       NaN
# 20296     20175     839       756            105    28.0    27       NaN
# 20297     20176     839       697            163    52.0    23       NaN
# 20298     20183     839       647              6    48.0     6       2.0
# 20299     20184     839       579             51    60.0     7       NaN
#
#       positionText  positionOrder  points  laps      time_x  milliseconds  \
# 20140            1              1     9.0    70   2:13:23.6     8003600.0
# 20141            2              2     6.0    70        +2.6     8006200.0
# 20142            3              3     4.0    70       +52.0     8055600.0
# 20143            4              4     3.0    68         NaN           NaN
# 20144            5              5     2.0    68         NaN           NaN
# 20145            6              6     0.0    67         NaN           NaN
# 20146            7              7     0.0    67         NaN           NaN
# 20147            8              8     0.0    65         NaN           NaN
# 20148            9              9     0.0    64         NaN           NaN
# 20149           10             10     0.0    64         NaN           NaN
# 20150           11             11     0.0    64         NaN           NaN
# 20151            R             12     0.0    62         NaN           NaN
# 20152            N             13     0.0    57         NaN           NaN
# 20153            R             14     0.0    49         NaN           NaN
# 20154            R             15     0.0    44         NaN           NaN
# 20155            R             16     0.0    43         NaN           NaN
# 20156            R             17     0.0    36         NaN           NaN
# 20157            R             18     0.0    26         NaN           NaN
# 20158            R             19     0.0     8         NaN           NaN
# 20159            R             20     0.0     5         NaN           NaN
# 20160            R             21     0.0     2         NaN           NaN
# 20161           10             10     0.0    64         NaN           NaN
# 20162            R             20     0.0     5         NaN           NaN
# 20163            1              1     9.0   100   3:13:18.7    11598700.0
# 20164            2              2     6.0    99         NaN           NaN
# 20165            3              3     4.0    98         NaN           NaN
# 20166            4              4     3.0    97         NaN           NaN
# 20167            5              5     2.0    95         NaN           NaN
# 20168            6              6     0.0    94         NaN           NaN
# 20169            7              7     0.0    94         NaN           NaN
# 20170            R              8     0.0    63         NaN           NaN
# 20171            R              9     0.0    38         NaN           NaN
# 20172            R             10     0.0     1         NaN           NaN
# 20173            R             11     0.0     0         NaN           NaN
# 20174            R             12     0.0     0         NaN           NaN
# 20175            R             13     0.0     0         NaN           NaN
# 20176            R             14     0.0     0         NaN           NaN
# 20177            R             15     0.0     0         NaN           NaN
# 20178            R             16     0.0     0         NaN           NaN
# 20179            R             17     0.0     0         NaN           NaN
# 20180            R             18     0.0     0         NaN           NaN
# 20181            R             19     0.0     0         NaN           NaN
# 20182            W             20     0.0     0         NaN           NaN
# 20183            W             21     0.0     0         NaN           NaN
# 20184            1              1     9.0   138  2:46:55.97    10015970.0
# 20185            2              2     6.0   137         NaN           NaN
# 20186            3              3     4.0   137         NaN           NaN
# 20187            4              4     3.0   137         NaN           NaN
# 20188            5              5     1.0   136         NaN           NaN
# 20189            6              6     0.0   136         NaN           NaN
# 20190            7              7     0.0   135         NaN           NaN
# 20191            8              8     0.0   135         NaN           NaN
# 20192            9              9     0.0   135         NaN           NaN
# 20193           10             10     0.0   135         NaN           NaN
# 20194           11             11     0.0   133         NaN           NaN
# 20195           12             12     0.0   133         NaN           NaN
# 20196           13             13     0.0   132         NaN           NaN
# 20197           14             14     0.0   131         NaN           NaN
# 20198           15             15     0.0   130         NaN           NaN
# 20199           16             16     0.0   128         NaN           NaN
# 20200           17             17     0.0   128         NaN           NaN
# 20201           18             18     0.0   128         NaN           NaN
# 20202           19             19     0.0   127         NaN           NaN
# 20203           20             20     0.0   126         NaN           NaN
# 20204           21             21     0.0   125         NaN           NaN
# 20205           22             22     0.0   123         NaN           NaN
# 20206           23             23     0.0   123         NaN           NaN
# 20207           24             24     0.0   122         NaN           NaN
# 20208            R             25     0.0   112         NaN           NaN
# 20209            R             26     0.0   111         NaN           NaN
# 20210            R             27     0.0   108         NaN           NaN
# 20211            R             28     0.0    64         NaN           NaN
# 20212            R             29     0.0    52         NaN           NaN
# 20213            R             30     0.0    42         NaN           NaN
# 20214            R             31     0.0    30         NaN           NaN
# 20215            R             32     0.0    25         NaN           NaN
# 20216            R             33     0.0    10         NaN           NaN
# 20217            5              5     1.0   136         NaN           NaN
# 20218            R             27     0.0   108         NaN           NaN
# 20219            1              1     9.0    42   2:02:53.7     7373700.0
# 20220            2              2     6.0    42        +0.4     7374100.0
# 20221            3              3     4.0    41         NaN           NaN
# 20222            4              4     3.0    40         NaN           NaN
# 20223            5              5     2.0    40         NaN           NaN
# 20224            6              6     0.0    40         NaN           NaN
# 20225            7              7     0.0    39         NaN           NaN
# 20226            8              8     0.0    39         NaN           NaN
# 20227            9              9     0.0    39         NaN           NaN
# 20228           10             10     0.0    38         NaN           NaN
# 20229           11             11     0.0    35         NaN           NaN
# 20230            R             12     0.0    32         NaN           NaN
# 20231            R             13     0.0    25         NaN           NaN
# 20232            R             14     0.0    19         NaN           NaN
# 20233            R             15     0.0    19         NaN           NaN
# 20234            R             16     0.0     9         NaN           NaN
# 20235            R             17     0.0     4         NaN           NaN
# 20236            R             18     0.0     0         NaN           NaN
# 20237            1              1     8.0    35   2:47:26.0    10046000.0
# 20238            2              2     6.0    35       +14.0    10060000.0
# 20239            3              3     4.0    35     +2:19.0    10185000.0
# 20240            4              4     4.0    35     +4:05.0    10291000.0
# 20241            5              5     2.0    34         NaN           NaN
# 20242            6              6     0.0    33         NaN           NaN
# 20243            7              7     0.0    33         NaN           NaN
# 20244            8              8     0.0    22         NaN           NaN
# 20245            9              9     0.0    30         NaN           NaN
# 20246           10             10     0.0    29         NaN           NaN
# 20247            R             11     0.0    22         NaN           NaN
# 20248            R             12     0.0    20         NaN           NaN
# 20249            R             13     0.0    15         NaN           NaN
# 20250            R             14     0.0     2         NaN           NaN
# 20251            1              1     9.0    64   2:57:52.8    10672800.0
# 20252            2              2     6.0    64       +25.7    10698500.0
# 20253            3              3     4.0    61         NaN           NaN
# 20254            4              4     3.0    61         NaN           NaN
# 20255            5              5     1.0    59         NaN           NaN
# 20256            6              6     0.0    56         NaN           NaN
# 20257            7              7     0.0    55         NaN           NaN
# 20258            8              8     0.0    52         NaN           NaN
# 20259            R              9     0.0    36         NaN           NaN
# 20260            R             10     0.0    14         NaN           NaN
# 20261            R             11     0.0    11         NaN           NaN
# 20262            R             12     0.0    10         NaN           NaN
# 20263            R             13     0.0     9         NaN           NaN
# 20264            R             14     0.0     6         NaN           NaN
# 20265            R             15     0.0     6         NaN           NaN
# 20266            R             16     0.0     5         NaN           NaN
# 20267            R             17     0.0     4         NaN           NaN
# 20268            R             18     0.0     3         NaN           NaN
# 20269            5              5     1.0    59         NaN           NaN
# 20270            6              6     0.0    56         NaN           NaN
# 20271            1              1     8.0    80   2:51:17.4    10277400.0
# 20272            2              2     3.0    80     +1:18.6    10356000.0
# 20273            3              3     4.0    80     +1:35.6    10373000.0
# 20274            4              4     3.0    75         NaN           NaN
# 20275            5              5     2.0    75         NaN           NaN
# 20276            6              6     0.0    72         NaN           NaN
# 20277            7              7     0.0    72         NaN           NaN
# 20278            R              8     0.0    56         NaN           NaN
# 20279            R              9     0.0    51         NaN           NaN
# 20280            R             10     0.0    48         NaN           NaN
# 20281            R             11     0.0    42         NaN           NaN
# 20282            R             12     0.0    39         NaN           NaN
# 20283            R             13     0.0    34         NaN           NaN
# 20284            R             14     0.0    29         NaN           NaN
# 20285            R             15     1.0    23         NaN           NaN
# 20286            R             16     0.0    22         NaN           NaN
# 20287            R             17     0.0    21         NaN           NaN
# 20288            R             18     0.0    17         NaN           NaN
# 20289            R             19     0.0    16         NaN           NaN
# 20290            R             20     0.0    15         NaN           NaN
# 20291            R             21     0.0    13         NaN           NaN
# 20292            R             22     0.0    13         NaN           NaN
# 20293            R             23     0.0    11         NaN           NaN
# 20294            R             24     0.0     7         NaN           NaN
# 20295            R             25     0.0     1         NaN           NaN
# 20296            R             26     0.0     0         NaN           NaN
# 20297            W             27     0.0     0         NaN           NaN
# 20298            2              2     3.0    80         NaN           NaN
# 20299            R             13     0.0    34         NaN           NaN
#
#        fastestLap  rank fastestLapTime  fastestLapSpeed  statusId  year  \
# 20140         NaN   NaN            NaN              NaN         1  1950
# 20141         NaN   NaN            NaN              NaN         1  1950
# 20142         NaN   NaN            NaN              NaN         1  1950
# 20143         NaN   NaN            NaN              NaN        12  1950
# 20144         NaN   NaN            NaN              NaN        12  1950
# 20145         NaN   NaN            NaN              NaN        13  1950
# 20146         NaN   NaN            NaN              NaN        13  1950
# 20147         NaN   NaN            NaN              NaN        15  1950
# 20148         NaN   NaN            NaN              NaN        16  1950
# 20149         NaN   NaN            NaN              NaN        16  1950
# 20150         NaN   NaN            NaN              NaN        16  1950
# 20151         NaN   NaN            NaN              NaN        44  1950
# 20152         NaN   NaN            NaN              NaN        62  1950
# 20153         NaN   NaN            NaN              NaN        60  1950
# 20154         NaN   NaN            NaN              NaN         5  1950
# 20155         NaN   NaN            NaN              NaN         7  1950
# 20156         NaN   NaN            NaN              NaN         5  1950
# 20157         NaN   NaN            NaN              NaN         8  1950
# 20158         NaN   NaN            NaN              NaN        51  1950
# 20159         NaN   NaN            NaN              NaN         6  1950
# 20160         NaN   NaN            NaN              NaN       126  1950
# 20161         NaN   NaN            NaN              NaN        16  1950
# 20162         NaN   NaN            NaN              NaN         6  1950
# 20163         NaN   NaN            NaN              NaN         1  1950
# 20164         NaN   NaN            NaN              NaN        11  1950
# 20165         NaN   NaN            NaN              NaN        12  1950
# 20166         NaN   NaN            NaN              NaN        13  1950
# 20167         NaN   NaN            NaN              NaN        15  1950
# 20168         NaN   NaN            NaN              NaN        16  1950
# 20169         NaN   NaN            NaN              NaN        16  1950
# 20170         NaN   NaN            NaN              NaN       109  1950
# 20171         NaN   NaN            NaN              NaN        44  1950
# 20172         NaN   NaN            NaN              NaN         3  1950
# 20173         NaN   NaN            NaN              NaN         3  1950
# 20174         NaN   NaN            NaN              NaN         3  1950
# 20175         NaN   NaN            NaN              NaN         3  1950
# 20176         NaN   NaN            NaN              NaN         3  1950
# 20177         NaN   NaN            NaN              NaN         3  1950
# 20178         NaN   NaN            NaN              NaN         3  1950
# 20179         NaN   NaN            NaN              NaN         3  1950
# 20180         NaN   NaN            NaN              NaN         3  1950
# 20181         NaN   NaN            NaN              NaN         4  1950
# 20182         NaN   NaN            NaN              NaN         5  1950
# 20183         NaN   NaN            NaN              NaN         3  1950
# 20184         NaN   NaN            NaN              NaN         1  1950
# 20185         NaN   NaN            NaN              NaN        11  1950
# 20186         NaN   NaN            NaN              NaN        11  1950
# 20187         NaN   NaN            NaN              NaN        11  1950
# 20188         NaN   NaN            NaN              NaN        12  1950
# 20189         NaN   NaN            NaN              NaN        12  1950
# 20190         NaN   NaN            NaN              NaN        13  1950
# 20191         NaN   NaN            NaN              NaN        13  1950
# 20192         NaN   NaN            NaN              NaN        13  1950
# 20193         NaN   NaN            NaN              NaN        13  1950
# 20194         NaN   NaN            NaN              NaN        15  1950
# 20195         NaN   NaN            NaN              NaN        15  1950
# 20196         NaN   NaN            NaN              NaN        16  1950
# 20197         NaN   NaN            NaN              NaN        20  1950
# 20198         NaN   NaN            NaN              NaN        18  1950
# 20199         NaN   NaN            NaN              NaN        88  1950
# 20200         NaN   NaN            NaN              NaN        88  1950
# 20201         NaN   NaN            NaN              NaN        88  1950
# 20202         NaN   NaN            NaN              NaN        45  1950
# 20203         NaN   NaN            NaN              NaN        55  1950
# 20204         NaN   NaN            NaN              NaN        53  1950
# 20205         NaN   NaN            NaN              NaN       112  1950
# 20206         NaN   NaN            NaN              NaN        20  1950
# 20207         NaN   NaN            NaN              NaN       116  1950
# 20208         NaN   NaN            NaN              NaN        70  1950
# 20209         NaN   NaN            NaN              NaN         7  1950
# 20210         NaN   NaN            NaN              NaN        51  1950
# 20211         NaN   NaN            NaN              NaN        44  1950
# 20212         NaN   NaN            NaN              NaN       126  1950
# 20213         NaN   NaN            NaN              NaN        51  1950
# 20214         NaN   NaN            NaN              NaN        67  1950
# 20215         NaN   NaN            NaN              NaN        85  1950
# 20216         NaN   NaN            NaN              NaN        44  1950
# 20217         NaN   NaN            NaN              NaN        12  1950
# 20218         NaN   NaN            NaN              NaN        51  1950
# 20219         NaN   NaN            NaN              NaN         1  1950
# 20220         NaN   NaN            NaN              NaN         1  1950
# 20221         NaN   NaN            NaN              NaN        11  1950
# 20222         NaN   NaN            NaN              NaN        12  1950
# 20223         NaN   NaN            NaN              NaN        12  1950
# 20224         NaN   NaN            NaN              NaN        12  1950
# 20225         NaN   NaN            NaN              NaN        13  1950
# 20226         NaN   NaN            NaN              NaN        13  1950
# 20227         NaN   NaN            NaN              NaN        13  1950
# 20228         NaN   NaN            NaN              NaN        14  1950
# 20229         NaN   NaN            NaN              NaN        17  1950
# 20230         NaN   NaN            NaN              NaN         5  1950
# 20231         NaN   NaN            NaN              NaN         6  1950
# 20232         NaN   NaN            NaN              NaN         3  1950
# 20233         NaN   NaN            NaN              NaN        22  1950
# 20234         NaN   NaN            NaN              NaN         5  1950
# 20235         NaN   NaN            NaN              NaN        94  1950
# 20236         NaN   NaN            NaN              NaN         3  1950
# 20237         NaN   NaN            NaN              NaN         1  1950
# 20238         NaN   NaN            NaN              NaN         1  1950
# 20239         NaN   NaN            NaN              NaN         1  1950
# 20240         NaN   NaN            NaN              NaN         1  1950
# 20241         NaN   NaN            NaN              NaN        11  1950
# 20242         NaN   NaN            NaN              NaN        12  1950
# 20243         NaN   NaN            NaN              NaN        12  1950
# 20244         NaN   NaN            NaN              NaN        13  1950
# 20245         NaN   NaN            NaN              NaN        15  1950
# 20246         NaN   NaN            NaN              NaN        16  1950
# 20247         NaN   NaN            NaN              NaN       108  1950
# 20248         NaN   NaN            NaN              NaN        51  1950
# 20249         NaN   NaN            NaN              NaN        25  1950
# 20250         NaN   NaN            NaN              NaN       108  1950
# 20251         NaN   NaN            NaN              NaN         1  1950
# 20252         NaN   NaN            NaN              NaN         1  1950
# 20253         NaN   NaN            NaN              NaN        13  1950
# 20254         NaN   NaN            NaN              NaN        13  1950
# 20255         NaN   NaN            NaN              NaN        15  1950
# 20256         NaN   NaN            NaN              NaN        18  1950
# 20257         NaN   NaN            NaN              NaN        48  1950
# 20258         NaN   NaN            NaN              NaN        55  1950
# 20259         NaN   NaN            NaN              NaN         5  1950
# 20260         NaN   NaN            NaN              NaN         5  1950
# 20261         NaN   NaN            NaN              NaN        25  1950
# 20262         NaN   NaN            NaN              NaN        25  1950
# 20263         NaN   NaN            NaN              NaN         5  1950
# 20264         NaN   NaN            NaN              NaN         5  1950
# 20265         NaN   NaN            NaN              NaN         5  1950
# 20266         NaN   NaN            NaN              NaN         5  1950
# 20267         NaN   NaN            NaN              NaN        25  1950
# 20268         NaN   NaN            NaN              NaN         5  1950
# 20269         NaN   NaN            NaN              NaN        15  1950
# 20270         NaN   NaN            NaN              NaN        18  1950
# 20271         NaN   NaN            NaN              NaN         1  1950
# 20272         NaN   NaN            NaN              NaN         1  1950
# 20273         NaN   NaN            NaN              NaN         1  1950
# 20274         NaN   NaN            NaN              NaN        15  1950
# 20275         NaN   NaN            NaN              NaN        15  1950
# 20276         NaN   NaN            NaN              NaN        18  1950
# 20277         NaN   NaN            NaN              NaN        18  1950
# 20278         NaN   NaN            NaN              NaN         6  1950
# 20279         NaN   NaN            NaN              NaN        21  1950
# 20280         NaN   NaN            NaN              NaN         6  1950
# 20281         NaN   NaN            NaN              NaN       108  1950
# 20282         NaN   NaN            NaN              NaN        31  1950
# 20283         NaN   NaN            NaN              NaN         5  1950
# 20284         NaN   NaN            NaN              NaN         6  1950
# 20285         NaN   NaN            NaN              NaN         6  1950
# 20286         NaN   NaN            NaN              NaN        25  1950
# 20287         NaN   NaN            NaN              NaN         5  1950
# 20288         NaN   NaN            NaN              NaN         5  1950
# 20289         NaN   NaN            NaN              NaN        23  1950
# 20290         NaN   NaN            NaN              NaN        31  1950
# 20291         NaN   NaN            NaN              NaN       110  1950
# 20292         NaN   NaN            NaN              NaN        51  1950
# 20293         NaN   NaN            NaN              NaN         5  1950
# 20294         NaN   NaN            NaN              NaN         7  1950
# 20295         NaN   NaN            NaN              NaN         5  1950
# 20296         NaN   NaN            NaN              NaN         5  1950
# 20297         NaN   NaN            NaN              NaN        54  1950
# 20298         NaN   NaN            NaN              NaN         1  1950
# 20299         NaN   NaN            NaN              NaN         5  1950
#
#        round  circuitId                name       date    time_y  \
# 20140      1          9  British Grand Prix 1950-05-13  15:00:00
# 20141      1          9  British Grand Prix 1950-05-13  15:00:00
# 20142      1          9  British Grand Prix 1950-05-13  15:00:00
# 20143      1          9  British Grand Prix 1950-05-13  15:00:00
# 20144      1          9  British Grand Prix 1950-05-13  15:00:00
# 20145      1          9  British Grand Prix 1950-05-13  15:00:00
# 20146      1          9  British Grand Prix 1950-05-13  15:00:00
# 20147      1          9  British Grand Prix 1950-05-13  15:00:00
# 20148      1          9  British Grand Prix 1950-05-13  15:00:00
# 20149      1          9  British Grand Prix 1950-05-13  15:00:00
# 20150      1          9  British Grand Prix 1950-05-13  15:00:00
# 20151      1          9  British Grand Prix 1950-05-13  15:00:00
# 20152      1          9  British Grand Prix 1950-05-13  15:00:00
# 20153      1          9  British Grand Prix 1950-05-13  15:00:00
# 20154      1          9  British Grand Prix 1950-05-13  15:00:00
# 20155      1          9  British Grand Prix 1950-05-13  15:00:00
# 20156      1          9  British Grand Prix 1950-05-13  15:00:00
# 20157      1          9  British Grand Prix 1950-05-13  15:00:00
# 20158      1          9  British Grand Prix 1950-05-13  15:00:00
# 20159      1          9  British Grand Prix 1950-05-13  15:00:00
# 20160      1          9  British Grand Prix 1950-05-13  15:00:00
# 20161      1          9  British Grand Prix 1950-05-13  15:00:00
# 20162      1          9  British Grand Prix 1950-05-13  15:00:00
# 20163      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20164      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20165      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20166      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20167      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20168      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20169      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20170      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20171      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20172      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20173      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20174      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20175      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20176      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20177      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20178      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20179      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20180      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20181      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20182      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20183      2          6   Monaco Grand Prix 1950-05-21  15:00:00
# 20184      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20185      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20186      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20187      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20188      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20189      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20190      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20191      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20192      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20193      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20194      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20195      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20196      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20197      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20198      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20199      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20200      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20201      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20202      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20203      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20204      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20205      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20206      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20207      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20208      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20209      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20210      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20211      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20212      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20213      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20214      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20215      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20216      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20217      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20218      3         19    Indianapolis 500 1950-05-30  15:00:00
# 20219      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20220      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20221      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20222      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20223      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20224      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20225      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20226      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20227      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20228      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20229      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20230      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20231      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20232      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20233      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20234      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20235      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20236      4         66    Swiss Grand Prix 1950-06-04  15:00:00
# 20237      5         13  Belgian Grand Prix 1950-06-18  15:00:00
# 20238      5         13  Belgian Grand Prix 1950-06-18  15:00:00
# 20239      5         13  Belgian Grand Prix 1950-06-18  15:00:00
# 20240      5         13  Belgian Grand Prix 1950-06-18  15:00:00
# 20241      5         13  Belgian Grand Prix 1950-06-18  15:00:00
# 20242      5         13  Belgian Grand Prix 1950-06-18  15:00:00
# 20243      5         13  Belgian Grand Prix 1950-06-18  15:00:00
# 20244      5         13  Belgian Grand Prix 1950-06-18  15:00:00
# 20245      5         13  Belgian Grand Prix 1950-06-18  15:00:00
# 20246      5         13  Belgian Grand Prix 1950-06-18  15:00:00
# 20247      5         13  Belgian Grand Prix 1950-06-18  15:00:00
# 20248      5         13  Belgian Grand Prix 1950-06-18  15:00:00
# 20249      5         13  Belgian Grand Prix 1950-06-18  15:00:00
# 20250      5         13  Belgian Grand Prix 1950-06-18  15:00:00
# 20251      6         55   French Grand Prix 1950-07-02  15:00:00
# 20252      6         55   French Grand Prix 1950-07-02  15:00:00
# 20253      6         55   French Grand Prix 1950-07-02  15:00:00
# 20254      6         55   French Grand Prix 1950-07-02  15:00:00
# 20255      6         55   French Grand Prix 1950-07-02  15:00:00
# 20256      6         55   French Grand Prix 1950-07-02  15:00:00
# 20257      6         55   French Grand Prix 1950-07-02  15:00:00
# 20258      6         55   French Grand Prix 1950-07-02  15:00:00
# 20259      6         55   French Grand Prix 1950-07-02  15:00:00
# 20260      6         55   French Grand Prix 1950-07-02  15:00:00
# 20261      6         55   French Grand Prix 1950-07-02  15:00:00
# 20262      6         55   French Grand Prix 1950-07-02  15:00:00
# 20263      6         55   French Grand Prix 1950-07-02  15:00:00
# 20264      6         55   French Grand Prix 1950-07-02  15:00:00
# 20265      6         55   French Grand Prix 1950-07-02  15:00:00
# 20266      6         55   French Grand Prix 1950-07-02  15:00:00
# 20267      6         55   French Grand Prix 1950-07-02  15:00:00
# 20268      6         55   French Grand Prix 1950-07-02  15:00:00
# 20269      6         55   French Grand Prix 1950-07-02  15:00:00
# 20270      6         55   French Grand Prix 1950-07-02  15:00:00
# 20271      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20272      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20273      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20274      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20275      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20276      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20277      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20278      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20279      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20280      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20281      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20282      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20283      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20284      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20285      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20286      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20287      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20288      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20289      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20290      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20291      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20292      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20293      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20294      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20295      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20296      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20297      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20298      7         14  Italian Grand Prix 1950-09-03  15:00:00
# 20299      7         14  Italian Grand Prix 1950-09-03  15:00:00
#
#                                                      url
# 20140  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20141  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20142  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20143  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20144  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20145  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20146  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20147  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20148  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20149  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20150  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20151  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20152  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20153  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20154  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20155  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20156  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20157  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20158  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20159  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20160  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20161  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20162  http://en.wikipedia.org/wiki/1950_British_Gran...
# 20163  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20164  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20165  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20166  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20167  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20168  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20169  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20170  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20171  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20172  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20173  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20174  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20175  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20176  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20177  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20178  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20179  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20180  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20181  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20182  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20183  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 20184  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20185  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20186  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20187  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20188  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20189  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20190  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20191  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20192  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20193  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20194  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20195  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20196  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20197  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20198  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20199  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20200  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20201  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20202  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20203  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20204  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20205  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20206  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20207  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20208  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20209  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20210  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20211  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20212  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20213  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20214  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20215  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20216  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20217  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20218  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 20219  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20220  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20221  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20222  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20223  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20224  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20225  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20226  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20227  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20228  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20229  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20230  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20231  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20232  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20233  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20234  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20235  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20236  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 20237  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 20238  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 20239  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 20240  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 20241  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 20242  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 20243  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 20244  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 20245  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 20246  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 20247  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 20248  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 20249  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 20250  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 20251  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20252  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20253  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20254  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20255  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20256  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20257  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20258  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20259  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20260  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20261  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20262  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20263  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20264  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20265  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20266  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20267  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20268  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20269  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20270  http://en.wikipedia.org/wiki/1950_French_Grand...
# 20271  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20272  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20273  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20274  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20275  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20276  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20277  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20278  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20279  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20280  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20281  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20282  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20283  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20284  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20285  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20286  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20287  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20288  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20289  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20290  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20291  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20292  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20293  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20294  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20295  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20296  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20297  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20298  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 20299  http://en.wikipedia.org/wiki/1950_Italian_Gran...

# %% [markdown]
# ### Helped resources
#
# Function which can be applied on 2 DFs
#
# https://stackoverflow.com/questions/13331698/how-to-apply-a-function-to-two-columns-of-pandas-dataframe
#
# https://stackoverflow.com/questions/67805424/problem-with-if-conditional-with-none-variable-in-dataframe-python

# %%
import numpy as np
List = [25,18,15,12,10,8,6,4,2,1] + [0 for i in range(25)]
Map = {float(i):List[i-1] for i in range(1,35)}
Map[0.0] = 0


def unified_system(x):
    final_point = 0
    
    # Actually there is no need of this since we fill nan values with 0
    if x[6] == np.nan or x[6] == None or x[6] is np.nan or x[6] == "NaN" or x[6] == "nan":
        return final_point
    final_point = Map[x[6]]
    if x[14] == 1 and x[6] <= 10.0:
        return final_point + 1
    return final_point

# %%
values = {'position':0.0}
result.fillna(value=values,inplace=True)

# %%
result['unified_points'] = result.apply(lambda x: unified_system(x) ,axis=1)

# %%
# Tool to check point for each race

result.loc[result['raceId'] == 834][['position','rank','unified_points']]
# Out:
#        position  rank  unified_points
# 20045       1.0   NaN              25
# 20046       2.0   NaN              18
# 20047       3.0   NaN              15
# 20048       4.0   NaN              12
# 20049       5.0   NaN              10
# 20050       6.0   NaN               8
# 20051       7.0   NaN               6
# 20052       0.0   NaN               0
# 20053       0.0   NaN               0
# 20054       0.0   NaN               0
# 20055       0.0   NaN               0
# 20056       0.0   NaN               0
# 20057       0.0   NaN               0
# 20058       0.0   NaN               0
# 20059       0.0   NaN               0
# 20060       0.0   NaN               0
# 20061       0.0   NaN               0
# 20062       0.0   NaN               0
# 20063       0.0   NaN               0
# 20064       0.0   NaN               0
# 20065       0.0   NaN               0

# %%
suggested_schema(result)
# Out:
# ['resultId INT',
#  'raceId INT',
#  'driverId INT',
#  'constructorId INT',
#  'number double precision',
#  'grid INT',
#  'position double precision',
#  'positionText VARCHAR(2)',
#  'positionOrder INT',
#  'points double precision',
#  'laps INT',
#  'time VARCHAR(11)',
#  'milliseconds double precision',
#  'fastestLap double precision',
#  'rank double precision',
#  'fastestLapTime VARCHAR(8)',
#  'fastestLapSpeed double precision',
#  'statusId INT',
#  'unified_points INT']

# %%
result_scheama = ['resultId INT PRIMARY KEY',
 'raceId INT REFERENCES races(raceId) ',
 'driverId INT REFERENCES drivers(driverId)',
 'constructorId INT',
 'number double precision',
 'grid INT',
 'position double precision',
 'positionText VARCHAR(5)',
 'positionOrder INT',
 'points double precision',
 'laps INT',
 'time VARCHAR(20)',
 'milliseconds double precision',
 'fastestLap double precision',
 'rank double precision',
 'fastestLapTime VARCHAR(25)',
 'fastestLapSpeed double precision',
 'statusId INT',
 'unified_points INT']

# %%
createTable(result_scheama,"formulaone","result")

# %%
inserting_value(result,"formulaone", "result")

# %%
sql("formulaone", """SELECT  r.points as everPoints, CONCAT(d.forename,' ', d.surname) as driverName FROM (SELECT driverId, SUM(unified_points) as points FROM result
    GROUP BY driverId) r JOIN drivers d ON r.driverId = d.driverId ORDER BY points DESC""")
# Out:
#      everpoints          drivername
# 0          4592      Lewis Hamilton
# 1          3910  Michael Schumacher
# 2          3288    Sebastian Vettel
# 3          2843     Fernando Alonso
# 4          2830      Kimi Räikkönen
# ..          ...                 ...
# 849           0       Antonio Creus
# 850           0     Sergey Sirotkin
# 851           0          Geoff Duke
# 852           0     Robert Doornbos
# 853           0     Lance Reventlow
#
# [854 rows x 2 columns]

# %%
sql("formulaone", """SELECT driverId, count(*) as wins FROM result WHERE position = 1.0 GROUP BY driverId ORDER BY wins DESC""")
# Out:
#      driverid  wins
# 0           1   103
# 1          30    91
# 2          20    53
# 3         117    51
# 4         102    41
# 5           4    32
# 6          95    31
# 7         328    27
# 8         373    25
# 9         182    25
# 10        579    24
# 11          3    23
# 12        137    23
# 13         71    22
# 14          8    21
# 15        830    21
# 16         57    20
# 17        475    16
# 18         18    15
# 19        356    14
# 20        224    14
# 21        289    14
# 22        647    13
# 23         14    13
# 24        207    12
# 25        178    12
# 26        199    12
# 27         22    11
# 28         13    11
# 29         35    11
# 30        222    10
# 31        822    10
# 32         77    10
# 33        238    10
# 34        231    10
# 35         17     9
# 36        817     8
# 37        235     8
# 38        304     8
# 39        163     7
# 40         31     7
# 41        358     6
# 42        119     6
# 43        479     6
# 44        172     6
# 45         23     6
# 46        203     6
# 47        341     6
# 48        642     5
# 49        223     5
# 50        187     5
# 51        105     5
# 52        177     5
# 53        360     4
# 54        844     4
# 55        364     4
# 56         56     4
# 57        123     3
# 58        578     3
# 59        202     3
# 60        403     3
# 61        581     3
# 62         49     3
# 63         65     3
# 64         21     3
# 65        657     2
# 66        345     2
# 67        498     2
# 68        219     2
# 69        175     2
# 70        815     2
# 71        427     2
# 72        173     2
# 73        221     2
# 74        309     2
# 75        346     2
# 76        476     2
# 77        386     1
# 78        839     1
# 79        509     1
# 80        641     1
# 81        766     1
# 82        145     1
# 83        559     1
# 84        320     1
# 85        375     1
# 86         44     1
# 87          9     1
# 88        255     1
# 89        526     1
# 90        593     1
# 91        628     1
# 92        394     1
# 93        577     1
# 94        525     1
# 95         15     1
# 96        842     1
# 97          5     1
# 98        786     1
# 99        347     1
# 100       327     1
# 101       230     1
# 102       250     1
# 103       611     1
# 104       200     1
# 105       306     1
# 106       404     1
# 107       813     1
# 108       385     1
# 109       449     1
# 110        55     1

# %%
# Q. We need to find no. of unique drivers who won the races
# -> 


sql("formulaone", """SELECT count(*) as drivers FROM (SELECT driverId, count(*) as wins FROM result WHERE position = 1.0 GROUP BY driverId ORDER BY wins DESC) v""")
# Out:
#    drivers
# 0      111

# %%
sql("formulaone", """SELECT *
                    FROM result r JOIN races ra 
                    ON r.raceId = ra.raceId
                    WHERE ra.date = (SELECT MAX(date) FROM races)""")
# Out:
#        resultid  raceid  driverid  constructorid  number  grid  position  \
# 0             1      18         1              1    22.0     1       1.0
# 1             2      18         2              2     3.0     5       2.0
# 2             3      18         3              3     7.0     7       3.0
# 3             4      18         4              4     5.0    11       4.0
# 4             5      18         5              1    23.0     3       5.0
# ...         ...     ...       ...            ...     ...   ...       ...
# 25455     25461    1076       849              3     6.0    18      16.0
# 25456     25462    1076         4            214    14.0    10      17.0
# 25457     25463    1076       830              9     1.0     2       0.0
# 25458     25464    1076        20            117     5.0    17       0.0
# 25459     25465    1076       832              6    55.0     9       0.0
#
#       positiontext  positionorder  points  laps         time  milliseconds  \
# 0                1              1    10.0    58  1:34:50.616     5690616.0
# 1                2              2     8.0    58       +5.478     5696094.0
# 2                3              3     6.0    58       +8.163     5698779.0
# 3                4              4     5.0    58      +17.181     5707797.0
# 4                5              5     4.0    58      +18.014     5708630.0
# ...            ...            ...     ...   ...          ...           ...
# 25455           16             16     0.0    57          NaN           NaN
# 25456           17             17     0.0    57          NaN           NaN
# 25457            R             18     0.0    38          NaN           NaN
# 25458            R             19     0.0    22          NaN           NaN
# 25459            R             20     0.0     1          NaN           NaN
#
#        fastestlap  rank fastestlaptime  fastestlapspeed  statusid  \
# 0            39.0   2.0       1:27.452          218.300         1
# 1            41.0   3.0       1:27.739          217.586         1
# 2            41.0   5.0       1:28.090          216.719         1
# 3            58.0   7.0       1:28.603          215.464         1
# 4            43.0   1.0       1:27.418          218.385         1
# ...           ...   ...            ...              ...       ...
# 25455        49.0  18.0       1:23.882          226.518        11
# 25456        57.0   2.0       1:20.846          235.024        11
# 25457        37.0   6.0       1:21.677          232.633         9
# 25458        17.0  19.0       1:25.189          223.042         3
# 25459         NaN   0.0            NaN              NaN        20
#
#        unified_points  raceid  year  round  circuitid                   name  \
# 0                  25      18  2008      1          1  Australian Grand Prix
# 1                  18      18  2008      1          1  Australian Grand Prix
# 2                  15      18  2008      1          1  Australian Grand Prix
# 3                  12      18  2008      1          1  Australian Grand Prix
# 4                  11      18  2008      1          1  Australian Grand Prix
# ...               ...     ...   ...    ...        ...                    ...
# 25455               0    1076  2022      3          1  Australian Grand Prix
# 25456               0    1076  2022      3          1  Australian Grand Prix
# 25457               0    1076  2022      3          1  Australian Grand Prix
# 25458               0    1076  2022      3          1  Australian Grand Prix
# 25459               0    1076  2022      3          1  Australian Grand Prix
#
#              date      time                                                url
# 0      2008-03-16  04:30:00  http://en.wikipedia.org/wiki/2008_Australian_G...
# 1      2008-03-16  04:30:00  http://en.wikipedia.org/wiki/2008_Australian_G...
# 2      2008-03-16  04:30:00  http://en.wikipedia.org/wiki/2008_Australian_G...
# 3      2008-03-16  04:30:00  http://en.wikipedia.org/wiki/2008_Australian_G...
# 4      2008-03-16  04:30:00  http://en.wikipedia.org/wiki/2008_Australian_G...
# ...           ...       ...                                                ...
# 25455  2022-04-10  05:00:00  http://en.wikipedia.org/wiki/2022_Australian_G...
# 25456  2022-04-10  05:00:00  http://en.wikipedia.org/wiki/2022_Australian_G...
# 25457  2022-04-10  05:00:00  http://en.wikipedia.org/wiki/2022_Australian_G...
# 25458  2022-04-10  05:00:00  http://en.wikipedia.org/wiki/2022_Australian_G...
# 25459  2022-04-10  05:00:00  http://en.wikipedia.org/wiki/2022_Australian_G...
#
# [25460 rows x 27 columns]

# %%
# Retired calculations:



# Handling null values
# import numpy as np

# def Len_test(x):
#     try:
#         if type(x) == float:
#             return 0
#         else:
#             return len(x)
#     except:
#         return 0

# str(result['time'].apply(Len_test).max())

# %%
string_format = "%s,%s"
list_of_tuple = [(1,'A'),(2,'B')]
args__ = ','.join([f"({string_format})" % i for i in list_of_tuple])
args__
# Out:
# '(1,A),(2,B)'
